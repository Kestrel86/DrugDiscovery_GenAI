# %% [markdown]
# # GLOW Model for Generating Molecular SMILES Strings
#
# This notebook implements a GLOW (Generative Latent Optimization with Wasserstein GANs) model to generate new, valid molecular structures in SMILES format based on a training dataset.

# %% [markdown]
# ## 1. Import Dependencies

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Define Hyperparameters

# %%
# Hyperparameters
LATENT_DIM = 128
HIDDEN_DIM = 512
NUM_FLOWS = 8
BATCH_SIZE = 10
LEARNING_RATE = 0.0001
NUM_EPOCHS = 50

# %% [markdown]
# ## 3. Dataset Processing
#
# Build vocabulary for SMILES strings and create a PyTorch dataset class.

# %%
# Define character vocabulary for SMILES strings
def build_vocabulary(smiles_list):
    chars = set()
    for smiles in smiles_list:
        chars.update(list(smiles))
    return {c: i for i, c in enumerate(sorted(chars))}, {i: c for i, c in enumerate(sorted(chars))}

# %%
# Dataset class for SMILES strings
class SMILESDataset(Dataset):
    def __init__(self, smiles_list, max_length=150, char_to_idx=None):
        self.smiles_list = smiles_list
        self.max_length = max_length
        
        if char_to_idx is None:
            self.char_to_idx, self.idx_to_char = build_vocabulary(smiles_list)
        else:
            self.char_to_idx = char_to_idx
            self.idx_to_char = {v: k for k, v in char_to_idx.items()}
        
        self.vocab_size = len(self.char_to_idx)
        
    def __len__(self):
        return len(self.smiles_list)
    
    def __getitem__(self, idx):
        smiles = self.smiles_list[idx]
        # One-hot encode the SMILES string
        encoded = torch.zeros(self.max_length, self.vocab_size)
        for i, char in enumerate(smiles[:self.max_length]):
            encoded[i, self.char_to_idx[char]] = 1.0
        
        # Pad with zeros
        if len(smiles) < self.max_length:
            encoded[len(smiles):, :] = 0.0
            
        return encoded

# %% [markdown]
# ## 4. Implementation of the GLOW Model Components
#
# ### 4.1 Activation Normalization Layer

# %%
# Define ActNorm layer (used in GLOW)
class ActNorm(nn.Module):
    def __init__(self, channels):
        super(ActNorm, self).__init__()
        self.loc = nn.Parameter(torch.zeros(1, channels, 1))
        self.scale = nn.Parameter(torch.ones(1, channels, 1))
        self.initialized = False

    def initialize(self, x):
        with torch.no_grad():
            flatten = x.permute(1, 0, 2).contiguous().view(x.shape[1], -1)
            mean = flatten.mean(1).view(1, -1, 1)
            std = flatten.std(1).view(1, -1, 1)
            
            self.loc.data.copy_(-mean)
            self.scale.data.copy_(1 / (std + 1e-6))
            
    def forward(self, x, ldj=None, reverse=False):
        if not self.initialized:
            self.initialize(x)
            self.initialized = True
            
        if reverse:
            return (x - self.loc) / self.scale, ldj
        else:
            z = self.scale * x + self.loc
            if ldj is not None:
                ldj = ldj + torch.sum(torch.log(torch.abs(self.scale)))
            return z, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.2 Invertible 1x1 Convolution

# %%
# Invertible 1x1 Convolution
class Invertible1x1Conv(nn.Module):
    def __init__(self, channels):
        super(Invertible1x1Conv, self).__init__()
        self.channels = channels
        
        # Initialize with random rotation matrix
        w_init = torch.qr(torch.randn(channels, channels))[0]
        self.weight = nn.Parameter(w_init)
        
    def forward(self, x, ldj=None, reverse=False):
        batch_size, _, seq_len = x.size()
        
        if reverse:
            weight = torch.inverse(self.weight)
        else:
            weight = self.weight
            
        z = F.conv1d(x, weight.unsqueeze(2))
        
        if ldj is not None:
            ldj = ldj + seq_len * torch.slogdet(weight)[1]
            
        return z, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.3 Affine Coupling Layer

# %%
# Affine Coupling Layer
class AffineCoupling(nn.Module):
    def __init__(self, channels, hidden_dim):
        super(AffineCoupling, self).__init__()
        
        self.net = nn.Sequential(
            nn.Conv1d(channels // 2, hidden_dim, 3, padding=1),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 1),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, channels, 3, padding=1)
        )
        
        # Initialize last layer with zeros for stability
        self.net[-1].weight.data.zero_()
        self.net[-1].bias.data.zero_()
        
        self.channels = channels
        
    def forward(self, x, ldj=None, reverse=False):
        x_a, x_b = x.chunk(2, dim=1)
        
        out = self.net(x_a)
        log_s, t = out.chunk(2, dim=1)
        
        # Constrain scaling
        log_s = torch.tanh(log_s) * 0.5
        s = torch.exp(log_s)
        
        if reverse:
            z_b = (x_b - t) / s
            z = torch.cat([x_a, z_b], dim=1)
            
            if ldj is not None:
                ldj = ldj - torch.sum(log_s)
        else:
            z_b = s * x_b + t
            z = torch.cat([x_a, z_b], dim=1)
            
            if ldj is not None:
                ldj = ldj + torch.sum(log_s)
                
        return z, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.4 Single Flow Step

# %%
# Single Flow Step
class FlowStep(nn.Module):
    def __init__(self, channels, hidden_dim):
        super(FlowStep, self).__init__()
        
        self.actnorm = ActNorm(channels)
        self.conv = Invertible1x1Conv(channels)
        self.coupling = AffineCoupling(channels, hidden_dim)
        
    def forward(self, x, ldj=None, reverse=False):
        if reverse:
            x, ldj = self.coupling.reverse(x, ldj)
            x, ldj = self.conv.reverse(x, ldj)
            x, ldj = self.actnorm.reverse(x, ldj)
        else:
            x, ldj = self.actnorm(x, ldj)
            x, ldj = self.conv(x, ldj)
            x, ldj = self.coupling(x, ldj)
            
        return x, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.5 Complete GLOW Model

# %%
# Complete GLOW model
class GLOW(nn.Module):
    def __init__(self, in_channels, hidden_dim, num_flows):
        super(GLOW, self).__init__()
        
        self.flows = nn.ModuleList([
            FlowStep(in_channels, hidden_dim) for _ in range(num_flows)
        ])
        
        self.in_channels = in_channels
        
    def forward(self, x, ldj=None):
        # Flatten one-hot encoding to channels
        batch_size, seq_len, vocab_size = x.size()
        x = x.transpose(1, 2).contiguous()  # [B, V, L]
        
        if ldj is None:
            ldj = torch.zeros(batch_size, device=x.device)
            
        for flow in self.flows:
            x, ldj = flow(x, ldj)
            
        return x, ldj
    
    def reverse(self, z, ldj=None):
        batch_size, _, seq_len = z.size()
        
        if ldj is None:
            ldj = torch.zeros(batch_size, device=z.device)
            
        for flow in reversed(self.flows):
            z, ldj = flow.reverse(z, ldj)
            
        # Convert back to one-hot format
        z = z.transpose(1, 2).contiguous()  # [B, L, V]
        
        return z, ldj
    
    def sample(self, num_samples, seq_len, device='cpu'):
        z = torch.randn(num_samples, self.in_channels, seq_len, device=device)
        samples, _ = self.reverse(z)
        return samples

# %% [markdown]
# ## 5. Training and Utility Functions

# %%
# Training function
def train_glow_model(model, dataloader, optimizer, device, epoch):
    model.train()
    total_loss = 0
    
    for batch_idx, batch in enumerate(dataloader):
        batch = batch.to(device)
        optimizer.zero_grad()
        
        # Forward pass
        z, ldj = model(batch)
        
        # Compute loss (negative log-likelihood)
        loss = 0.5 * torch.sum(z**2) / len(batch) - torch.mean(ldj)
        
        # Backward pass
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        if batch_idx % 10 == 0:
            print(f'Epoch: {epoch}, Batch: {batch_idx}, Loss: {loss.item():.4f}')
    
    return total_loss / len(dataloader)

# %%
# Sampling and converting back to SMILES
def sample_and_decode(model, idx_to_char, num_samples, max_length, device='cpu'):
    model.eval()
    samples = model.sample(num_samples, max_length, device)
    
    # Convert to one-hot indices
    samples = samples.argmax(dim=2)
    
    # Convert to SMILES strings
    smiles_list = []
    for sample in samples:
        smiles = ''.join([idx_to_char[idx.item()] for idx in sample if idx.item() in idx_to_char])
        smiles_list.append(smiles)
    
    return smiles_list

# %%
# Check validity of generated SMILES
def check_validity(smiles_list):
    valid_smiles = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            valid_smiles.append(smiles)
    
    return valid_smiles, len(valid_smiles) / len(smiles_list) if len(smiles_list) > 0 else 0

# %% [markdown]
# ## 6. Main Execution Function

# %%
# Main function to run the training and sampling
def main(smiles_data, num_epochs=NUM_EPOCHS):
    # Prepare the dataset
    smiles_dataset = SMILESDataset(smiles_data)
    train_data, val_data = train_test_split(smiles_dataset, test_size=0.1, random_state=42)
    
    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=BATCH_SIZE)
    
    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = GLOW(smiles_dataset.vocab_size, HIDDEN_DIM, NUM_FLOWS).to(device)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    
    # Training loop
    for epoch in range(1, num_epochs + 1):
        train_loss = train_glow_model(model, train_loader, optimizer, device, epoch)
        print(f'Epoch {epoch}, Average loss: {train_loss:.4f}')
        
        # Generate samples every 10 epochs
        if epoch % 10 == 0 or epoch == num_epochs:
            with torch.no_grad():
                samples = sample_and_decode(model, smiles_dataset.idx_to_char, 10, smiles_dataset.max_length, device)
                valid_samples, validity_rate = check_validity(samples)
                
                print(f"Generated samples (validity rate: {validity_rate:.2%}):")
                for i, s in enumerate(samples[:5]):
                    print(f"{i+1}. {s}")
                    
                print(f"Valid samples:")
                for i, s in enumerate(valid_samples[:5]):
                    print(f"{i+1}. {s}")
    
    # Save the trained model
    torch.save({
        'model_state_dict': model.state_dict(),
        'char_to_idx': smiles_dataset.char_to_idx,
        'idx_to_char': smiles_dataset.idx_to_char,
        'max_length': smiles_dataset.max_length
    }, 'glow_smiles_model.pt')
    
    return model, smiles_dataset.char_to_idx, smiles_dataset.idx_to_char

# %% [markdown]
# ## 7. Example Usage with Sample Data

# %%
# Example usage with sample data
# Use this section as a template for your own dataset
df = pd.read_csv('dataset/train.txt')
df = df.drop(columns=["SPLIT"])
print(df.shape)
df.head()
# Out:
# (1584663, 1)
#                                    SMILES
# 0  CCCS(=O)c1ccc2[nH]c(=NC(=O)OC)[nH]c2c1
# 1    CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1
# 2     Cc1c(Cl)cccc1Nc1ncccc1C(=O)OCC(O)CO
# 3        Cn1cnc2c1c(=O)n(CC(O)CO)c(=O)n2C
# 4          CC1Oc2ccc(Cl)cc2N(CC(O)CO)C1=O

# %% [markdown]
# ## 8. Run Model Training
#
# Uncomment and run the following cell to train the model.

# %%
small_df = df.head(990)
print(f"Using {len(small_df)} samples for training")


# Train the model with the smaller dataset
model, char_to_idx, idx_to_char = main(small_df['SMILES'].tolist())
# Out:
# Using 990 samples for training
# Epoch: 1, Batch: 0, Loss: 1720.0635
# Epoch: 1, Batch: 10, Loss: -676.7039
# Epoch: 1, Batch: 20, Loss: 2116061757440.0000
# Epoch: 1, Batch: 30, Loss: -2665.0054
# Epoch: 1, Batch: 40, Loss: -5578.4004
# Epoch: 1, Batch: 50, Loss: 375670800384.0000
# Epoch: 1, Batch: 60, Loss: -9393.4727
# Epoch: 1, Batch: 70, Loss: -10748.1328
# Epoch: 1, Batch: 80, Loss: -12065.9932
# Epoch 1, Average loss: 874248795762.2327
# Epoch: 2, Batch: 0, Loss: 302141374464.0000
# Epoch: 2, Batch: 10, Loss: -14882.5625
# Epoch: 2, Batch: 20, Loss: -15272.7344
# Epoch: 2, Batch: 30, Loss: 165434884096.0000
# Epoch: 2, Batch: 40, Loss: -19446.9023
# Epoch: 2, Batch: 50, Loss: -20000.6172
# Epoch: 2, Batch: 60, Loss: 107590041600.0000
# Epoch: 2, Batch: 70, Loss: -20778.1543
# Epoch: 2, Batch: 80, Loss: -22818.6426
# Epoch 2, Average loss: 66312142860.4783
# Epoch: 3, Batch: 0, Loss: -24074.9648
# Epoch: 3, Batch: 10, Loss: -24758.0059
# Epoch: 3, Batch: 20, Loss: -24831.8535
# Epoch: 3, Batch: 30, Loss: -25292.5234
# Epoch: 3, Batch: 40, Loss: 83831209984.0000
# Epoch: 3, Batch: 50, Loss: -27143.0000
# Epoch: 3, Batch: 60, Loss: 60152492032.0000
# Epoch: 3, Batch: 70, Loss: 37510164480.0000
# Epoch: 3, Batch: 80, Loss: 44018180096.0000
# Epoch 3, Average loss: 48999091577.1126
# Epoch: 4, Batch: 0, Loss: -29767.7207
# Epoch: 4, Batch: 10, Loss: 65241554944.0000
# Epoch: 4, Batch: 20, Loss: 60206477312.0000
# Epoch: 4, Batch: 30, Loss: 109581303808.0000
# Epoch: 4, Batch: 40, Loss: -30560.9648
# Epoch: 4, Batch: 50, Loss: -31359.7441
# Epoch: 4, Batch: 60, Loss: 80998522880.0000
# Epoch: 4, Batch: 70, Loss: -31437.8301
# Epoch: 4, Batch: 80, Loss: -34627.6836
# Epoch: 18, Batch: 10, Loss: -44218.6797
# Epoch: 18, Batch: 20, Loss: -43121.0352
# Epoch: 18, Batch: 30, Loss: -44287.6992
# Epoch: 18, Batch: 40, Loss: 12859900928.0000
# Epoch: 18, Batch: 50, Loss: 8550138368.0000
# Epoch: 18, Batch: 60, Loss: -43284.7070
# Epoch: 18, Batch: 70, Loss: -43581.4570
# Epoch: 18, Batch: 80, Loss: -44647.5039
# Epoch 18, Average loss: 6175806024.6299
# Epoch: 19, Batch: 0, Loss: 6897140736.0000
# Epoch: 19, Batch: 10, Loss: -43880.2734
# Epoch: 19, Batch: 20, Loss: -45817.8125
# Epoch: 19, Batch: 30, Loss: -41438.6133
# Epoch: 19, Batch: 40, Loss: -44263.6016
# Epoch: 19, Batch: 50, Loss: 4322999296.0000
# Epoch: 19, Batch: 60, Loss: -44342.2578
# Epoch: 19, Batch: 70, Loss: 8645437440.0000
# Epoch: 19, Batch: 80, Loss: -44514.0938
# Epoch 19, Average loss: 1510865293.6634
# Epoch: 20, Batch: 0, Loss: -44623.8984
# Epoch: 20, Batch: 10, Loss: 3854111488.0000
# Epoch: 20, Batch: 20, Loss: -44317.6680
# Epoch: 20, Batch: 30, Loss: 4350660608.0000
# Epoch: 20, Batch: 40, Loss: -44935.0078
# Epoch: 20, Batch: 50, Loss: 2677861888.0000
# Epoch: 20, Batch: 60, Loss: -42474.8008
# Epoch: 20, Batch: 70, Loss: -41804.1328
# Epoch: 20, Batch: 80, Loss: -40554.7344
# Epoch 20, Average loss: 4165125783.3824
# Generated samples (validity rate: 0.00%):
# 1. cCccnC1cccCccc=c(c(c((ccccCc(OcCOO1ccCcO=Ccccc)c=cC1cccOc(=(Cccc)cc(c(3cccc(C31ccCccc3Cccccccc(cCC(ccCc1CcCcC=cccccOccccc1cCCO)ccCcCc1OcCCc2cc=cc1cccc
# 2. cc=C2cccOccccc(c(ccccccCnc((cc3OCccc=c2[CCCncc2ccccccccCcnOcc2n(cccccC1(cO()c=COc(==Ccc(c=(Cc1cCcccccc1c1c2cccccCc)C2ccccccccc=cOOcccCc)c)cC(=Ccccc(Cc
# 3. nCcccccC1CC1(Cc(cc11cccc=(ccnccC21O2(cCccc(c)ccco(cC(OccO(cCcC2(ccccccc(cccccccc)nCcccCOcCcCccc=OccCcccc1)cccc(11c1c=ccCcCCCcCccccccCC)cccc2OCCCcccccC
# 4. cCc2Ccc(CnC=cCC)n1cccccc1=C=OCc2cCc2)cc=ccc((C(cc2[ccCFc1ccnOC1=ccnCccCccCcccc=c2cccC=ccc=1c=1=ccCcccncFCOScOccc1ccc1cc=(ccCcc(cccCCccC2OCcccccccccc1)
# 5. CcCcccc1Cncc=1cccOcCccCOcccccC(cC1ccCccc3c=CcCcc(cncccc1cCcO(1c(ccccCcc2nCcc[ccCcccCc=Oc(cccnc3(cccC1ccccCncccccOFccFcCccccn=ncCnccccCccC)=[cccC((ccc=
# Valid samples:
# [19:09:07] SMILES Parse Error: syntax error while parsing: cCccnC1cccCccc=c(c(c((ccccCc(OcCOO1ccCcO=Ccccc)c=cC1cccOc(=(Cccc)cc(c(3cccc(C31ccCccc3Cccccccc(cCC(ccCc1CcCcC=cccccOccccc1cCCO)ccCcCc1OcCCc2cc=cc1cccc
# [19:09:07] SMILES Parse Error: Failed parsing SMILES 'cCccnC1cccCccc=c(c(c((ccccCc(OcCOO1ccCcO=Ccccc)c=cC1cccOc(=(Cccc)cc(c(3cccc(C31ccCccc3Cccccccc(cCC(ccCc1CcCcC=cccccOccccc1cCCO)ccCcCc1OcCCc2cc=cc1cccc' for input: 'cCccnC1cccCccc=c(c(c((ccccCc(OcCOO1ccCcO=Ccccc)c=cC1cccOc(=(Cccc)cc(c(3cccc(C31ccCccc3Cccccccc(cCC(ccCc1CcCcC=cccccOccccc1cCCO)ccCcCc1OcCCc2cc=cc1cccc'
# [19:09:07] SMILES Parse Error: syntax error while parsing: cc=C2cccOccccc(c(ccccccCnc((cc3OCccc=c2[CCCncc2ccccccccCcnOcc2n(cccccC1(cO()c=COc(==Ccc(c=(Cc1cCcccccc1c1c2cccccCc)C2ccccccccc=cOOcccCc)c)cC(=Ccccc(Cc
# [19:09:07] SMILES Parse Error: Failed parsing SMILES 'cc=C2cccOccccc(c(ccccccCnc((cc3OCccc=c2[CCCncc2ccccccccCcnOcc2n(cccccC1(cO()c=COc(==Ccc(c=(Cc1cCcccccc1c1c2cccccCc)C2ccccccccc=cOOcccCc)c)cC(=Ccccc(Cc' for input: 'cc=C2cccOccccc(c(ccccccCnc((cc3OCccc=c2[CCCncc2ccccccccCcnOcc2n(cccccC1(cO()c=COc(==Ccc(c=(Cc1cCcccccc1c1c2cccccCc)C2ccccccccc=cOOcccCc)c)cC(=Ccccc(Cc'
# [19:09:07] SMILES Parse Error: syntax error while parsing: nCcccccC1CC1(Cc(cc11cccc=(ccnccC21O2(cCccc(c)ccco(cC(OccO(cCcC2(ccccccc(cccccccc)nCcccCOcCcCccc=OccCcccc1)cccc(11c1c=ccCcCCCcCccccccCC)cccc2OCCCcccccC
# [19:09:07] SMILES Parse Error: Failed parsing SMILES 'nCcccccC1CC1(Cc(cc11cccc=(ccnccC21O2(cCccc(c)ccco(cC(OccO(cCcC2(ccccccc(cccccccc)nCcccCOcCcCccc=OccCcccc1)cccc(11c1c=ccCcCCCcCccccccCC)cccc2OCCCcccccC' for input: 'nCcccccC1CC1(Cc(cc11cccc=(ccnccC21O2(cCccc(c)ccco(cC(OccO(cCcC2(ccccccc(cccccccc)nCcccCOcCcCccc=OccCcccc1)cccc(11c1c=ccCcCCCcCccccccCC)cccc2OCCCcccccC'
# [19:09:07] SMILES Parse Error: extra close parentheses while parsing: cCc2Ccc(CnC=cCC)n1cccccc1=C=OCc2cCc2)cc=ccc((C(cc2[ccCFc1ccnOC1=ccnCccCccCcccc=c2cccC=ccc=1c=1=ccCcccncFCOScOccc1ccc1cc=(ccCcc(cccCCccC2OCcccccccccc1)
# [19:09:07] SMILES Parse Error: Failed parsing SMILES 'cCc2Ccc(CnC=cCC)n1cccccc1=C=OCc2cCc2)cc=ccc((C(cc2[ccCFc1ccnOC1=ccnCccCccCcccc=c2cccC=ccc=1c=1=ccCcccncFCOScOccc1ccc1cc=(ccCcc(cccCCccC2OCcccccccccc1)' for input: 'cCc2Ccc(CnC=cCC)n1cccccc1=C=OCc2cCc2)cc=ccc((C(cc2[ccCFc1ccnOC1=ccnCccCccCcccc=c2cccC=ccc=1c=1=ccCcccncFCOScOccc1ccc1cc=(ccCcc(cccCCccC2OCcccccccccc1)'
# [19:09:07] SMILES Parse Error: syntax error while parsing: CcCcccc1Cncc=1cccOcCccCOcccccC(cC1ccCccc3c=CcCcc(cncccc1cCcO(1c(ccccCcc2nCcc[ccCcccCc=Oc(cccnc3(cccC1ccccCncccccOFccFcCccccn=ncCnccccCccC)=[cccC((ccc=
# [19:09:07] SMILES Parse Error: Failed parsing SMILES 'CcCcccc1Cncc=1cccOcCccCOcccccC(cC1ccCccc3c=CcCcc(cncccc1cCcO(1c(ccccCcc2nCcc[ccCcccCc=Oc(cccnc3(cccC1ccccCncccccOFccFcCccccn=ncCnccccCccC)=[cccC((ccc=' for input: 'CcCcccc1Cncc=1cccOcCccCOcccccC(cC1ccCccc3c=CcCcc(cncccc1cCcO(1c(ccccCcc2nCcc[ccCcccCc=Oc(cccnc3(cccC1ccccCncccccOFccFcCccccn=ncCnccccCccC)=[cccC((ccc='
# [19:09:07] SMILES Parse Error: syntax error while parsing: =c)cCcO21n[c=c(cCCC1=c[Cc11(cCccc=cccCccc1cc12cccCcccc(cccCCcccc(OcccC3cC2ccccccCCc(Cc(cccc(CO[C=nCC1nC(cccncCc=c=ccc=cc=ccCcOc=cccccc1cCcccc(cCcccc1n
# [19:09:07] SMILES Parse Error: Failed parsing SMILES '=c)cCcO21n[c=c(cCCC1=c[Cc11(cCccc=cccCccc1cc12cccCcccc(cccCCcccc(OcccC3cC2ccccccCCc(Cc(cccc(CO[C=nCC1nC(cccncCc=c=ccc=cc=ccCcOc=cccccc1cCcccc(cCcccc1n' for input: '=c)cCcO21n[c=c(cCCC1=c[Cc11(cCccc=cccCccc1cc12cccCcccc(cccCCcccc(OcccC3cC2ccccccCCc(Cc(cccc(CO[C=nCC1nC(cccncCc=c=ccc=cc=ccCcOc=cccccc1cCcccc(cCcccc1n'
# [19:09:07] SMILES Parse Error: syntax error while parsing: cC(c1C2c1c=()cC1(Ccc1Cc)(ccCOC1c2ccCcc1CCcc(cccccccc(cccC(c=ccccccc=cOccccc(cccCccOcCccCCc(=cFc12(c2cccCCccccccccCccc=O(cnCcc1CCcnCcc(=c1=n13cc1cCccc=
# [19:09:07] SMILES Parse Error: Failed parsing SMILES 'cC(c1C2c1c=()cC1(Ccc1Cc)(ccCOC1c2ccCcc1CCcc(cccccccc(cccC(c=ccccccc=cOccccc(cccCccOcCccCCc(=cFc12(c2cccCCccccccccCccc=O(cnCcc1CCcnCcc(=c1=n13cc1cCccc=' for input: 'cC(c1C2c1c=()cC1(Ccc1Cc)(ccCOC1c2ccCcc1CCcc(cccccccc(cccC(c=ccccccc=cOccccc(cccCccOcCccCCc(=cFc12(c2cccCCccccccccCccc=O(cnCcc1CCcnCcc(=c1=n13cc1cCccc='
# [19:09:07] SMILES Parse Error: syntax error while parsing: )C2ccCOcCCcc2(1cCCcc(Cc1(cccccnCcCccOcCccccCccOc1=Ccc1cO(cc1ccccc2cc=CcOcccCcc=cccc1==(=Oc1cCcCn=c1Cc(ccOccccCcccC=cCccccCcc)ccccc(cCCnOOCO2cO(ccc1cO1
# [19:09:07] SMILES Parse Error: Failed parsing SMILES ')C2ccCOcCCcc2(1cCCcc(Cc1(cccccnCcCccOcCccccCccOc1=Ccc1cO(cc1ccccc2cc=CcOcccCcc=cccc1==(=Oc1cCcCn=c1Cc(ccOccccCcccC=cCccccCcc)ccccc(cCCnOOCO2cO(ccc1cO1' for input: ')C2ccCOcCCcc2(1cCCcc(Cc1(cccccnCcCccOcCccccCccOc1=Ccc1cO(cc1ccccc2cc=CcOcccCcc=cccc1==(=Oc1cCcCn=c1Cc(ccOccccCcccC=cCccccCcc)ccccc(cCCnOOCO2cO(ccc1cO1'
# [19:09:07] SMILES Parse Error: syntax error while parsing: (c13ccccccccCFccc1cc=cccc=c1cO2cccccC=c2ccccccccccccccCC(cccncccc2C1ccccC(ccccc((ccccc[cCOc=c=CcOccCc(cc1=Ccccc=c)cccCCcc((cCcccc(OcccO=2C=cc(O1ccCccc
# [19:09:07] SMILES Parse Error: Failed parsing SMILES '(c13ccccccccCFccc1cc=cccc=c1cO2cccccC=c2ccccccccccccccCC(cccncccc2C1ccccC(ccccc((ccccc[cCOc=c=CcOccCc(cc1=Ccccc=c)cccCCcc((cCcccc(OcccO=2C=cc(O1ccCccc' for input: '(c13ccccccccCFccc1cc=cccc=c1cO2cccccC=c2ccccccccccccccCC(cccncccc2C1ccccC(ccccc((ccccc[cCOc=c=CcOccCc(cc1=Ccccc=c)cccCCcc((cCcccc(OcccO=2C=cc(O1ccCccc'
# [19:09:07] SMILES Parse Error: syntax error while parsing: c(ccc(cccc(C1cC2n13cccccc(c(c(cC(1(cCFcC(c((cccccCCcOccCcc(112cc=c2cCcccC(1cCccOccc1Ccc=ccC1ccccOc)CO1=c1cc1c(cOcccccCCCccccc1ccccc2OccC==2c1Cc(cccncc
# [19:09:07] SMILES Parse Error: Failed parsing SMILES 'c(ccc(cccc(C1cC2n13cccccc(c(c(cC(1(cCFcC(c((cccccCCcOccCcc(112cc=c2cCcccC(1cCccOccc1Ccc=ccC1ccccOc)CO1=c1cc1c(cOcccccCCCccccc1ccccc2OccC==2c1Cc(cccncc' for input: 'c(ccc(cccc(C1cC2n13cccccc(c(c(cC(1(cCFcC(c((cccccCCcOccCcc(112cc=c2cCcccC(1cCccOccc1Ccc=ccC1ccccOc)CO1=c1cc1c(cOcccccCCCccccc1ccccc2OccC==2c1Cc(cccncc'
# Epoch: 21, Batch: 0, Loss: -41914.1719
# Epoch: 21, Batch: 10, Loss: -41375.5000
# Epoch: 21, Batch: 20, Loss: 8343726080.0000
# Epoch: 40, Batch: 50, Loss: 1402105856.0000
# Epoch: 40, Batch: 60, Loss: -50053.8711
# Epoch: 40, Batch: 70, Loss: -50394.1523
# Epoch: 40, Batch: 80, Loss: 437714784.0000
# Epoch 40, Average loss: 421597852.3988
# Generated samples (validity rate: 0.00%):
# 1. 2CCC=c2CCCOcOcC2(CcCcCC(Cn)C2cNc=C(CCOCO=2ccn=C21CC())COCccCCC(c((CcCC2n=ccCCC(CCcCC(CCOn2=CC11n)cccCC1CNCCnc)=C(=COCCC((c=2CCCO2C=CCC=C(CCnC1222C((=)
# 2. OcCCC2C)(1=2Cc=cn=C()O1CC(cCCCc2cC1(C1CO=(Cnccc(CCCCcCCC=c(=ncNC1nCCCCC=CC1)=)CCcc2(cCc(=CCOO2CccCCnC1cOC(OCCOCCO21c(c=CCC((CcccCCOcCC22C)(Cc)=(ccc(cC
# 3. C)cC2C)CC(cCc2Cc2CCC)((CCOCOCC==2CcO2(C((ncC1(CcC1cCC2c(CC=(=1CC1(CCOCCC(nc2)(CCCcN11C(C(2Cc1c1CCcC(Cc11CHCCC(2=c2(12O=2NC=n(CCcC(CC(CC2=CCCOOC=CCCCO)
# 4. cCC2=CCCCccC=CCCC1c((2CC(C=(CcC2((CC=cCC)(Cc(C1CC)CNCC1CC12CCC(21cCc=cOCc2CC2(ccCC2CC(c1CCC21ccC(C=Occc=CCCc11CNCCCC1OO1C=(C22n))Cc(=1C1cCCCCCCcCcCOC(
# 5. n)2NCCSCc(=CO=C(2n==12Cc)C=cCCCC)(CC(OC(CC2c2CcCCc(Cc21=)c(CCOC)C(C(C)Nn(C2Cn1cN1=c((cCC=cCCC=2(CCccCCn2CC(2Cn(nC)CcNCC=C=cCC2CCcC((3Cc(2C=NC)cc22C2c1
# Valid samples:
# [19:13:03] SMILES Parse Error: syntax error while parsing: 2CCC=c2CCCOcOcC2(CcCcCC(Cn)C2cNc=C(CCOCO=2ccn=C21CC())COCccCCC(c((CcCC2n=ccCCC(CCcCC(CCOn2=CC11n)cccCC1CNCCnc)=C(=COCCC((c=2CCCO2C=CCC=C(CCnC1222C((=)
# [19:13:03] SMILES Parse Error: Failed parsing SMILES '2CCC=c2CCCOcOcC2(CcCcCC(Cn)C2cNc=C(CCOCO=2ccn=C21CC())COCccCCC(c((CcCC2n=ccCCC(CCcCC(CCOn2=CC11n)cccCC1CNCCnc)=C(=COCCC((c=2CCCO2C=CCC=C(CCnC1222C((=)' for input: '2CCC=c2CCCOcOcC2(CcCcCC(Cn)C2cNc=C(CCOCO=2ccn=C21CC())COCccCCC(c((CcCC2n=ccCCC(CCcCC(CCOn2=CC11n)cccCC1CNCCnc)=C(=COCCC((c=2CCCO2C=CCC=C(CCnC1222C((=)'
# [19:13:03] SMILES Parse Error: extra close parentheses while parsing: OcCCC2C)(1=2Cc=cn=C()O1CC(cCCCc2cC1(C1CO=(Cnccc(CCCCcCCC=c(=ncNC1nCCCCC=CC1)=)CCcc2(cCc(=CCOO2CccCCnC1cOC(OCCOCCO21c(c=CCC((CcccCCOcCC22C)(Cc)=(ccc(cC
# [19:13:03] SMILES Parse Error: Failed parsing SMILES 'CCCcC(CCCC1CCCCc((COCC)C2Ccl2CnNCCCCC2ccc2CCC=O)(NC==C2c1=(c1=c22C2CCcCCCCn(()1(=nCCCCC)cCCc(cnCC=2CCCN)(CC(CCOCCCBc1Cc)C2CCC=nc(CC(N2Cc2(c1N2C1C((cNO' for input: 'CCCcC(CCCC1CCCCc((COCC)C2Ccl2CnNCCCCC2ccc2CCC=O)(NC==C2c1=(c1=c22C2CCcCCCCn(()1(=nCCCCC)cCCc(cnCC=2CCCN)(CC(CCOCCCBc1Cc)C2CCC=nc(CC(N2Cc2(c1N2C1C((cNO'
# [19:13:03] SMILES Parse Error: syntax error while parsing: CCC(=1n=cN2CC(CnCcCCCC=(CNC2CN(C1CCOnCCCCCO=(Nc(=cccCC(cOcc=(CON(CCCC(CCCNN2NCncC1C(C1CCCcOCcC)nCCC2COcCCccC1=(CCC(CCnNC1=(cc=(N(C=(CcCC(O=C(CcC=CC=(C
# [19:13:03] SMILES Parse Error: Failed parsing SMILES 'CCC(=1n=cN2CC(CnCcCCCC=(CNC2CN(C1CCOnCCCCCO=(Nc(=cccCC(cOcc=(CON(CCCC(CCCNN2NCncC1C(C1CCCcOCcC)nCCC2COcCCccC1=(CCC(CCnNC1=(cc=(N(C=(CcCC(O=C(CcC=CC=(C' for input: 'CCC(=1n=cN2CC(CnCcCCCC=(CNC2CN(C1CCOnCCCCCO=(Nc(=cccCC(cOcc=(CON(CCCC(CCCNN2NCncC1C(C1CCCcOCcC)nCCC2COcCCccC1=(CCC(CCnNC1=(cc=(N(C=(CcCC(O=C(CcC=CC=(C'
# [19:13:03] SMILES Parse Error: syntax error while parsing: CcOCCC(n=1((CCN2cC2CccC(C(c=nCC(cC2nCCCCNOccc(nC=c(c(C12C)CCcC1OCOcCcCC)(C2C(C2CcCcccC(Ccc)OCCccCCN(=(1CCCCCCCCCC((3NCC2NCcnCCCC(CC2(c]2cCccncc=(CC=nc
# [19:13:03] SMILES Parse Error: Failed parsing SMILES 'CcOCCC(n=1((CCN2cC2CccC(C(c=nCC(cC2nCCCCNOccc(nC=c(c(C12C)CCcC1OCOcCcCC)(C2C(C2CcCcccC(Ccc)OCCccCCN(=(1CCCCCCCCCC((3NCC2NCcnCCCC(CC2(c]2cCccncc=(CC=nc' for input: 'CcOCCC(n=1((CCN2cC2CccC(C(c=nCC(cC2nCCCCNOccc(nC=c(c(C12C)CCcC1OCOcCcCC)(C2C(C2CcCcccC(Ccc)OCCccCCN(=(1CCCCCCCCCC((3NCC2NCcnCCCC(CC2(c]2cCccncc=(CC=nc'
# Epoch: 41, Batch: 0, Loss: -50804.6914
# Epoch: 41, Batch: 10, Loss: 329183776.0000
# Epoch: 41, Batch: 20, Loss: -50571.0312
# Epoch: 41, Batch: 30, Loss: -50741.7539
# Epoch: 41, Batch: 40, Loss: -50526.8633
# Epoch: 41, Batch: 50, Loss: -49902.5781
# Epoch: 41, Batch: 60, Loss: -50769.7930
# Epoch: 41, Batch: 70, Loss: -52028.5156
# Epoch: 41, Batch: 80, Loss: -49954.1406
# Epoch 41, Average loss: 97702651.7593
# Epoch: 42, Batch: 0, Loss: -50720.9336
# Epoch: 42, Batch: 10, Loss: -51146.8867
# Epoch: 42, Batch: 20, Loss: 206853184.0000
# Epoch: 42, Batch: 30, Loss: -49789.8203
# Epoch: 42, Batch: 40, Loss: -51241.8047
# Epoch: 42, Batch: 50, Loss: -51997.1719
# Epoch: 42, Batch: 60, Loss: 240928672.0000
# Epoch: 42, Batch: 70, Loss: 223446880.0000
# Epoch: 42, Batch: 80, Loss: -52251.3711
# Epoch 42, Average loss: 93071762.7725
# Epoch: 43, Batch: 0, Loss: -49905.4336
# Epoch: 43, Batch: 10, Loss: 28308144128.0000
# Epoch: 43, Batch: 20, Loss: -47807.1250
# Epoch: 43, Batch: 30, Loss: 1701910272.0000
# Epoch: 43, Batch: 40, Loss: -49271.7188
# Epoch: 43, Batch: 50, Loss: -49691.7930
# Epoch: 43, Batch: 60, Loss: -50271.6016
# Epoch: 43, Batch: 70, Loss: 815574080.0000
# Epoch: 43, Batch: 80, Loss: -50262.3828
# Epoch 43, Average loss: 1527758071.5653
# Epoch: 44, Batch: 0, Loss: -48727.4609
# Epoch: 44, Batch: 10, Loss: -51694.6367
# Epoch: 44, Batch: 20, Loss: 362436384.0000
# Epoch: 44, Batch: 30, Loss: 299938368.0000
# Epoch: 44, Batch: 40, Loss: -50528.7891
# Epoch: 44, Batch: 50, Loss: -49456.4453
# Epoch: 44, Batch: 60, Loss: -51809.4336
# Epoch: 44, Batch: 70, Loss: -52008.5234
# Epoch: 44, Batch: 80, Loss: -50581.1602
# Epoch 44, Average loss: 311719427.8257
# Epoch: 45, Batch: 0, Loss: -50310.8594
# Epoch: 45, Batch: 10, Loss: -48509.5469
# Epoch: 45, Batch: 20, Loss: 588523392.0000

# %% [markdown]
# ## 9. Generate New SMILES Strings
#
# Once the model is trained, uncomment and run this cell to generate new molecules.

# %%
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
with torch.no_grad():
	generated_smiles = sample_and_decode(model, idx_to_char, 20, 150, device)
	valid_samples, validity_rate = check_validity(generated_smiles)

print(f"\nFinal generated samples (validity rate: {validity_rate:.2%}):")
for i, s in enumerate(valid_samples[:10]):
	print(f"{i+1}. {s}")
# Out:
# Final generated samples (validity rate: 0.00%):
# [18:48:36] SMILES Parse Error: syntax error while parsing: Oc(ccc-)NOOccc2Ccc)OO)Oc1ccc2n)cccC)ccccc)c1))Cc1)ccccOncc2Cc2CccO)C2)COC)OO)Oc1c)ccCC2cCcOCccc)Oc)c2cc3)Occc)2COCccc))2CCc2(2N2cccc2C)OO)c)ccO)cCccOc
# [18:48:36] SMILES Parse Error: Failed parsing SMILES 'Oc(ccc-)NOOccc2Ccc)OO)Oc1ccc2n)cccC)ccccc)c1))Cc1)ccccOncc2Cc2CccO)C2)COC)OO)Oc1c)ccCC2cCcOCccc)Oc)c2cc3)Occc)2COCccc))2CCc2(2N2cccc2C)OO)c)ccO)cCccOc' for input: 'Oc(ccc-)NOOccc2Ccc)OO)Oc1ccc2n)cccC)ccccc)c1))Cc1)ccccOncc2Cc2CccO)C2)COC)OO)Oc1c)ccCC2cCcOCccc)Oc)c2cc3)Occc)2COCccc))2CCc2(2N2cccc2C)OO)c)ccO)cCccOc'
# [18:48:36] SMILES Parse Error: extra close parentheses while parsing
# [18:48:36] SMILES Parse Error: Failed parsing SMILES 'cNC)cOcccOccOcccc2ccc2ON(cc2cCcCc2cccccOcc2cNc1OcccNc)))OcOCC=O)ccNOOcccc(c)Oc2OCcccc2Occcc-Oc)c)ccc)Cc2OOOccOOccC)OCCCNcOcNc)c1c)CccON2Cccc2O3)cC=)Cc' for input: 'cNC)cOcccOccOcccc2ccc2ON(cc2cCcCc2cccccOcc2cNc1OcccNc)))OcOCC=O)ccNOOcccc(c)Oc2OCcccc2Occcc-Oc)c)ccc)Cc2OOOccOOccC)OCCCNcOcNc)c1c)CccON2Cccc2O3)cC=)Cc'
# [18:48:36] SMILES Parse Error: extra close parentheses while parsing: ccc)cOcOCccc2cc=Occc)O(ONOOcccCOcCcCO))ccc2CcOcnO2c2cccc2)c2cO2CccccOOcccOCOccc-)cccOO)))c)ccCcccOc2ccccCcc=ccc(c)Occc)c)CcOOc))(COc2cO(OcOcOccccO)cOc
# [18:48:36] SMILES Parse Error: Failed parsing SMILES 'ccc)cOcOCccc2cc=Occc)O(ONOOcccCOcCcCO))ccc2CcOcnO2c2cccc2)c2cO2CccccOOcccOCOccc-)cccOO)))c)ccCcccOc2ccccCcc=ccc(c)Occc)c)CcOOc))(COc2cO(OcOcOccccO)cOc' for input: 'ccc)cOcOCccc2cc=Occc)O(ONOOcccCOcCcCO))ccc2CcOcnO2c2cccc2)c2cO2CccccOOcccOCOccc-)cccOO)))c)ccCcccOc2ccccCcc=ccc(c)Occc)c)CcOOc))(COc2cO(OcOcOccccO)cOc'

# %% [markdown]
# ## 10. Using Your Own Dataset
#
# You can load your own SMILES data and train the model on it.

# %%
# Load your own data
# Example 1: Loading from a CSV file with a 'smiles' column
# your_df = pd.read_csv('your_smiles_data.csv')
# smiles_list = your_df['smiles'].tolist()

# Example 2: Directly define from your data string
# long_smiles = "CCCS(=O)c1ccc2[nH]c(=NC(=O)OC)[nH]c2c11CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc12Cc1c(Cl)cccc1Nc1ncccc1C(=O)OCC(O)CO3Cn1cnc2c1c(=O)n(CC(O)CO)c(=O)n2C4CC1Oc2ccc(Cl)cc2N(CC(O)CO)C1=O"
# # Parse into individual compounds if needed
# smiles_list = [long_smiles]  # or split it if it contains multiple compounds

# Run the model
# model, char_to_idx, idx_to_char = main(smiles_list, num_epochs=50)

# %% [markdown]
# ## 11. Visualize Generated Molecules
#
# This optional section shows how to visualize generated molecules.

# %%
# Uncomment to install RDKit visualization tools
# !pip install rdkit-pypi

from rdkit.Chem import Draw
import matplotlib.pyplot as plt
from IPython.display import display

def visualize_molecules(smiles_list, ncols=3):
    mols = [Chem.MolFromSmiles(s) for s in smiles_list if Chem.MolFromSmiles(s) is not None]
    if len(mols) == 0:
        print("No valid molecules to visualize")
        return
        
    # Calculate number of rows needed
    nrows = (len(mols) + ncols - 1) // ncols
    
    # Create subplot
    fig = plt.figure(figsize=(ncols*3, nrows*3))
    
    for i, mol in enumerate(mols):
        ax = fig.add_subplot(nrows, ncols, i+1)
        img = Draw.MolToImage(mol, size=(300, 300))
        ax.imshow(img)
        ax.set_title(f"Molecule {i+1}")
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# Example usage:
visualize_molecules(valid_samples[:9])
# Out:
# No valid molecules to visualize

# %% [markdown]
# ## 12. Save and Load Models
