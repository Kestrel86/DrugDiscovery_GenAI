# %% [markdown]
# # GLOW Model for Generating Molecular SMILES Strings
#
# This notebook implements a GLOW (Generative Latent Optimization with Wasserstein GANs) model to generate new, valid molecular structures in SMILES format based on a training dataset.

# %% [markdown]
# ## 1. Import Dependencies

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Define Hyperparameters

# %%
# Hyperparameters
LATENT_DIM = 128
HIDDEN_DIM = 512
NUM_FLOWS = 8
BATCH_SIZE = 10
LEARNING_RATE = 0.0001
NUM_EPOCHS = 50

# %% [markdown]
# ## 3. Dataset Processing
#
# Build vocabulary for SMILES strings and create a PyTorch dataset class.

# %%
# Define character vocabulary for SMILES strings
def build_vocabulary(smiles_list):
    chars = set()
    for smiles in smiles_list:
        chars.update(list(smiles))
    return {c: i for i, c in enumerate(sorted(chars))}, {i: c for i, c in enumerate(sorted(chars))}

# %%
# Dataset class for SMILES strings
class SMILESDataset(Dataset):
    def __init__(self, smiles_list, max_length=150, char_to_idx=None):
        self.smiles_list = smiles_list
        self.max_length = max_length
        
        if char_to_idx is None:
            self.char_to_idx, self.idx_to_char = build_vocabulary(smiles_list)
        else:
            self.char_to_idx = char_to_idx
            self.idx_to_char = {v: k for k, v in char_to_idx.items()}
        
        self.vocab_size = len(self.char_to_idx)
        
    def __len__(self):
        return len(self.smiles_list)
    
    def __getitem__(self, idx):
        smiles = self.smiles_list[idx]
        # One-hot encode the SMILES string
        encoded = torch.zeros(self.max_length, self.vocab_size)
        for i, char in enumerate(smiles[:self.max_length]):
            encoded[i, self.char_to_idx[char]] = 1.0
        
        # Pad with zeros
        if len(smiles) < self.max_length:
            encoded[len(smiles):, :] = 0.0
            
        return encoded

# %% [markdown]
# ## 4. Implementation of the GLOW Model Components
#
# ### 4.1 Activation Normalization Layer

# %%
# Define ActNorm layer (used in GLOW)
class ActNorm(nn.Module):
    def __init__(self, channels):
        super(ActNorm, self).__init__()
        self.loc = nn.Parameter(torch.zeros(1, channels, 1))
        self.scale = nn.Parameter(torch.ones(1, channels, 1))
        self.initialized = False

    def initialize(self, x):
        with torch.no_grad():
            flatten = x.permute(1, 0, 2).contiguous().view(x.shape[1], -1)
            mean = flatten.mean(1).view(1, -1, 1)
            std = flatten.std(1).view(1, -1, 1)
            
            self.loc.data.copy_(-mean)
            self.scale.data.copy_(1 / (std + 1e-6))
            
    def forward(self, x, ldj=None, reverse=False):
        if not self.initialized:
            self.initialize(x)
            self.initialized = True
            
        if reverse:
            return (x - self.loc) / self.scale, ldj
        else:
            z = self.scale * x + self.loc
            if ldj is not None:
                ldj = ldj + torch.sum(torch.log(torch.abs(self.scale)))
            return z, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.2 Invertible 1x1 Convolution

# %%
# Invertible 1x1 Convolution
class Invertible1x1Conv(nn.Module):
    def __init__(self, channels):
        super(Invertible1x1Conv, self).__init__()
        self.channels = channels
        
        # Initialize with random rotation matrix
        w_init = torch.qr(torch.randn(channels, channels))[0]
        self.weight = nn.Parameter(w_init)
        
    def forward(self, x, ldj=None, reverse=False):
        batch_size, _, seq_len = x.size()
        
        if reverse:
            weight = torch.inverse(self.weight)
        else:
            weight = self.weight
            
        z = F.conv1d(x, weight.unsqueeze(2))
        
        if ldj is not None:
            ldj = ldj + seq_len * torch.slogdet(weight)[1]
            
        return z, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.3 Affine Coupling Layer

# %%
# Affine Coupling Layer
class AffineCoupling(nn.Module):
    def __init__(self, channels, hidden_dim):
        super(AffineCoupling, self).__init__()
        
        self.net = nn.Sequential(
            nn.Conv1d(channels // 2, hidden_dim, 3, padding=1),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 1),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, channels, 3, padding=1)
        )
        
        # Initialize last layer with zeros for stability
        self.net[-1].weight.data.zero_()
        self.net[-1].bias.data.zero_()
        
        self.channels = channels
        
    def forward(self, x, ldj=None, reverse=False):
        x_a, x_b = x.chunk(2, dim=1)
        
        out = self.net(x_a)
        log_s, t = out.chunk(2, dim=1)
        
        # Constrain scaling
        log_s = torch.tanh(log_s) * 0.5
        s = torch.exp(log_s)
        
        if reverse:
            z_b = (x_b - t) / s
            z = torch.cat([x_a, z_b], dim=1)
            
            if ldj is not None:
                ldj = ldj - torch.sum(log_s)
        else:
            z_b = s * x_b + t
            z = torch.cat([x_a, z_b], dim=1)
            
            if ldj is not None:
                ldj = ldj + torch.sum(log_s)
                
        return z, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.4 Single Flow Step

# %%
# Single Flow Step
class FlowStep(nn.Module):
    def __init__(self, channels, hidden_dim):
        super(FlowStep, self).__init__()
        
        self.actnorm = ActNorm(channels)
        self.conv = Invertible1x1Conv(channels)
        self.coupling = AffineCoupling(channels, hidden_dim)
        
    def forward(self, x, ldj=None, reverse=False):
        if reverse:
            x, ldj = self.coupling.reverse(x, ldj)
            x, ldj = self.conv.reverse(x, ldj)
            x, ldj = self.actnorm.reverse(x, ldj)
        else:
            x, ldj = self.actnorm(x, ldj)
            x, ldj = self.conv(x, ldj)
            x, ldj = self.coupling(x, ldj)
            
        return x, ldj
    
    def reverse(self, z, ldj=None):
        return self.forward(z, ldj, reverse=True)

# %% [markdown]
# ### 4.5 Complete GLOW Model

# %%
# Complete GLOW model
class GLOW(nn.Module):
    def __init__(self, in_channels, hidden_dim, num_flows):
        super(GLOW, self).__init__()
        
        self.flows = nn.ModuleList([
            FlowStep(in_channels, hidden_dim) for _ in range(num_flows)
        ])
        
        self.in_channels = in_channels
        
    def forward(self, x, ldj=None):
        # Flatten one-hot encoding to channels
        batch_size, seq_len, vocab_size = x.size()
        x = x.transpose(1, 2).contiguous()  # [B, V, L]
        
        if ldj is None:
            ldj = torch.zeros(batch_size, device=x.device)
            
        for flow in self.flows:
            x, ldj = flow(x, ldj)
            
        return x, ldj
    
    def reverse(self, z, ldj=None):
        batch_size, _, seq_len = z.size()
        
        if ldj is None:
            ldj = torch.zeros(batch_size, device=z.device)
            
        for flow in reversed(self.flows):
            z, ldj = flow.reverse(z, ldj)
            
        # Convert back to one-hot format
        z = z.transpose(1, 2).contiguous()  # [B, L, V]
        
        return z, ldj
    
    def sample(self, num_samples, seq_len, device='cpu'):
        z = torch.randn(num_samples, self.in_channels, seq_len, device=device)
        samples, _ = self.reverse(z)
        return samples

# %% [markdown]
# ## 5. Training and Utility Functions

# %%
# Training function
def train_glow_model(model, dataloader, optimizer, device, epoch):
    model.train()
    total_loss = 0
    
    for batch_idx, batch in enumerate(dataloader):
        batch = batch.to(device)
        optimizer.zero_grad()
        
        # Forward pass
        z, ldj = model(batch)
        
        # Compute loss (negative log-likelihood)
        loss = 0.5 * torch.sum(z**2) / len(batch) - torch.mean(ldj)
        
        # Backward pass
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        if batch_idx % 10 == 0:
            print(f'Epoch: {epoch}, Batch: {batch_idx}, Loss: {loss.item():.4f}')
    
    return total_loss / len(dataloader)

# %%
# Sampling and converting back to SMILES
def sample_and_decode(model, idx_to_char, num_samples, max_length, device='cpu'):
    model.eval()
    samples = model.sample(num_samples, max_length, device)
    
    # Convert to one-hot indices
    samples = samples.argmax(dim=2)
    
    # Convert to SMILES strings
    smiles_list = []
    for sample in samples:
        smiles = ''.join([idx_to_char[idx.item()] for idx in sample if idx.item() in idx_to_char])
        smiles_list.append(smiles)
    
    return smiles_list

# %%
# Check validity of generated SMILES
def check_validity(smiles_list):
    valid_smiles = []
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            valid_smiles.append(smiles)
    
    return valid_smiles, len(valid_smiles) / len(smiles_list) if len(smiles_list) > 0 else 0

# %% [markdown]
# ## 6. Main Execution Function

# %%
# Main function to run the training and sampling
def main(smiles_data, num_epochs=NUM_EPOCHS):
    # Prepare the dataset
    smiles_dataset = SMILESDataset(smiles_data)
    train_data, val_data = train_test_split(smiles_dataset, test_size=0.1, random_state=42)
    
    train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=BATCH_SIZE)
    
    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = GLOW(smiles_dataset.vocab_size, HIDDEN_DIM, NUM_FLOWS).to(device)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    
    # Training loop
    for epoch in range(1, num_epochs + 1):
        train_loss = train_glow_model(model, train_loader, optimizer, device, epoch)
        print(f'Epoch {epoch}, Average loss: {train_loss:.4f}')
        
        # Generate samples every 10 epochs
        if epoch % 10 == 0 or epoch == num_epochs:
            with torch.no_grad():
                samples = sample_and_decode(model, smiles_dataset.idx_to_char, 10, smiles_dataset.max_length, device)
                valid_samples, validity_rate = check_validity(samples)
                
                print(f"Generated samples (validity rate: {validity_rate:.2%}):")
                for i, s in enumerate(samples[:5]):
                    print(f"{i+1}. {s}")
                    
                print(f"Valid samples:")
                for i, s in enumerate(valid_samples[:5]):
                    print(f"{i+1}. {s}")
    
    # Save the trained model
    torch.save({
        'model_state_dict': model.state_dict(),
        'char_to_idx': smiles_dataset.char_to_idx,
        'idx_to_char': smiles_dataset.idx_to_char,
        'max_length': smiles_dataset.max_length
    }, 'glow_smiles_model.pt')
    
    return model, smiles_dataset.char_to_idx, smiles_dataset.idx_to_char

# %% [markdown]
# ## 7. Example Usage with Sample Data

# %%
# Example usage with sample data
# Use this section as a template for your own dataset
df = pd.read_csv('dataset/train.txt')
df = df.drop(columns=["SPLIT"])
print(df.shape)
df.head()
# Out:
# (1584663, 1)
#                                    SMILES
# 0  CCCS(=O)c1ccc2[nH]c(=NC(=O)OC)[nH]c2c1
# 1    CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1
# 2     Cc1c(Cl)cccc1Nc1ncccc1C(=O)OCC(O)CO
# 3        Cn1cnc2c1c(=O)n(CC(O)CO)c(=O)n2C
# 4          CC1Oc2ccc(Cl)cc2N(CC(O)CO)C1=O

# %% [markdown]
# ## 8. Run Model Training
#
# Uncomment and run the following cell to train the model.

# %%
small_df = df.head(990)
print(f"Using {len(small_df)} samples for training")


# Train the model with the smaller dataset
model, char_to_idx, idx_to_char = main(small_df['SMILES'].tolist())
# Out:
# Using 990 samples for training
# C:\Users\valde\AppData\Local\Temp\ipykernel_4716\2684719987.py:8: UserWarning: torch.qr is deprecated in favor of torch.linalg.qr and will be removed in a future PyTorch release.
# The boolean parameter 'some' has been replaced with a string parameter 'mode'.
# Q, R = torch.qr(A, some)
# should be replaced with
# Q, R = torch.linalg.qr(A, 'reduced' if some else 'complete') (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\BatchLinearAlgebra.cpp:2428.)
#   w_init = torch.qr(torch.randn(channels, channels))[0]
# Epoch: 1, Batch: 0, Loss: 1686.4832
# Epoch: 1, Batch: 10, Loss: 6697155297280.0000
# Epoch: 1, Batch: 20, Loss: 681.7671
# Epoch: 1, Batch: 30, Loss: 2611588366336.0000
# Epoch: 1, Batch: 40, Loss: 5671071252480.0000
# Epoch: 1, Batch: 50, Loss: 1040258695168.0000
# Epoch: 1, Batch: 60, Loss: -7356.2964
# Epoch: 1, Batch: 70, Loss: 1904146513920.0000
# Epoch: 1, Batch: 80, Loss: 667609858048.0000
# Epoch 1, Average loss: 5394155552622.4707
# Epoch: 2, Batch: 0, Loss: 1362398019584.0000
# Epoch: 2, Batch: 10, Loss: 300844646400.0000
# Epoch: 2, Batch: 20, Loss: -14022.0156
# Epoch: 2, Batch: 30, Loss: 1402845921280.0000
# Epoch: 2, Batch: 40, Loss: -14532.3203
# Epoch: 2, Batch: 50, Loss: 498803605504.0000
# Epoch: 2, Batch: 60, Loss: 266583048192.0000
# Epoch: 2, Batch: 70, Loss: -14860.6943
# Epoch: 2, Batch: 80, Loss: 280871698432.0000
# Epoch 2, Average loss: 554154430897.6296
# Epoch: 3, Batch: 0, Loss: 539740471296.0000
# Epoch: 3, Batch: 10, Loss: 1180896067584.0000
# Epoch: 3, Batch: 20, Loss: 333319405568.0000
# Epoch: 3, Batch: 30, Loss: 195102015488.0000
# Epoch: 3, Batch: 40, Loss: -13110.9238
# Epoch: 3, Batch: 50, Loss: 479653658624.0000
# Epoch: 3, Batch: 60, Loss: 164737810432.0000
# Epoch: 3, Batch: 70, Loss: -14511.9385
# Epoch: 3, Batch: 80, Loss: 70693879808.0000
# Epoch 3, Average loss: 274967612169.2212
# Epoch: 4, Batch: 0, Loss: 228684447744.0000
# Epoch: 4, Batch: 10, Loss: 228127817728.0000
# Epoch: 4, Batch: 20, Loss: 535364567040.0000
# Epoch: 4, Batch: 30, Loss: 766901878784.0000
# Epoch: 4, Batch: 40, Loss: 214237757440.0000
# Epoch: 4, Batch: 50, Loss: 57250729984.0000
# Epoch: 4, Batch: 60, Loss: 405490368512.0000
# Epoch: 4, Batch: 70, Loss: 539176599552.0000
# Epoch: 4, Batch: 80, Loss: 269166395392.0000
# Epoch 4, Average loss: 200496588764.8819
# Epoch: 5, Batch: 0, Loss: 153202114560.0000
# Epoch: 5, Batch: 10, Loss: 273302765568.0000
# Epoch: 5, Batch: 20, Loss: 131505643520.0000
# Epoch: 5, Batch: 30, Loss: 37726404608.0000
# Epoch: 5, Batch: 40, Loss: -20241.8789
# Epoch: 5, Batch: 50, Loss: 119661912064.0000
# Epoch: 5, Batch: 60, Loss: 151408164864.0000
# Epoch: 5, Batch: 70, Loss: 34097704960.0000
# Epoch: 5, Batch: 80, Loss: 45708738560.0000
# Epoch 5, Average loss: 120654290089.3636
# Epoch: 6, Batch: 0, Loss: 96810319872.0000
# Epoch: 6, Batch: 10, Loss: 94629888000.0000
# Epoch: 6, Batch: 20, Loss: -20207.8320
# Epoch: 6, Batch: 30, Loss: 137354149888.0000
# Epoch: 6, Batch: 40, Loss: 59189637120.0000
# Epoch: 6, Batch: 50, Loss: 193335312384.0000
# Epoch: 6, Batch: 60, Loss: 88822030336.0000
# Epoch: 6, Batch: 70, Loss: 36051095552.0000
# Epoch: 6, Batch: 80, Loss: -19172.8203
# Epoch 6, Average loss: 93379996786.4112
# Epoch: 7, Batch: 0, Loss: 107050205184.0000
# Epoch: 7, Batch: 10, Loss: 139251695616.0000
# Epoch: 7, Batch: 20, Loss: 102747799552.0000
# Epoch: 7, Batch: 30, Loss: 55094099968.0000
# Epoch: 7, Batch: 40, Loss: 130943000576.0000
# Epoch: 7, Batch: 50, Loss: -18768.2656
# Epoch: 7, Batch: 60, Loss: 22109300736.0000
# Epoch: 7, Batch: 70, Loss: 81185873920.0000
# Epoch: 7, Batch: 80, Loss: 93739098112.0000
# Epoch 7, Average loss: 77937325959.6697
# Epoch: 8, Batch: 0, Loss: 290305605632.0000
# Epoch: 8, Batch: 10, Loss: 206195458048.0000
# Epoch: 8, Batch: 20, Loss: 44241223680.0000
# Epoch: 8, Batch: 30, Loss: 105623396352.0000
# Epoch: 8, Batch: 40, Loss: -18789.1719
# Epoch: 8, Batch: 50, Loss: 177977933824.0000
# Epoch: 8, Batch: 60, Loss: 188283797504.0000
# Epoch: 8, Batch: 70, Loss: 47995916288.0000
# Epoch: 8, Batch: 80, Loss: 36499931136.0000
# Epoch 8, Average loss: 68577011500.8371
# Epoch: 9, Batch: 0, Loss: 68820828160.0000
# Epoch: 9, Batch: 10, Loss: 62408212480.0000
# Epoch: 9, Batch: 20, Loss: 84118511616.0000
# Epoch: 9, Batch: 30, Loss: 53572165632.0000
# Epoch: 9, Batch: 40, Loss: 56010489856.0000
# Epoch: 9, Batch: 50, Loss: 11819094016.0000
# Epoch: 9, Batch: 60, Loss: 69945851904.0000
# Epoch: 9, Batch: 70, Loss: 8985793536.0000
# Epoch: 9, Batch: 80, Loss: -19854.8008
# Epoch 9, Average loss: 40124859816.7163
# Epoch: 10, Batch: 0, Loss: 51203739648.0000
# Epoch: 10, Batch: 10, Loss: 14195712000.0000
# Epoch: 10, Batch: 20, Loss: 41152888832.0000
# Epoch: 10, Batch: 30, Loss: 6655161344.0000
# Epoch: 10, Batch: 40, Loss: 29771905024.0000
# Epoch: 10, Batch: 50, Loss: 22647054336.0000
# Epoch: 10, Batch: 60, Loss: -20218.5938
# Epoch: 10, Batch: 70, Loss: -14845.9424
# Epoch: 10, Batch: 80, Loss: -18857.5352
# Epoch 10, Average loss: 32049461213.6579
# Generated samples (validity rate: 0.00%):
# 1. ccCcCcccOcc1cC2c(ccnc2Oc1Cc=CONNcNC=CCcccccC1c(CccccOCC1c1ccCccnn(OCccc(c=cOcC(cOCCc=ccccn(=2c)cc=cncc(cccN=1CcC=CcnOOcc(cCcc1c)ccOccCccCcNCNcCccccCCc
# 2. )c)cn)1ccccccccOCcNc)CN)CcccNCcCccOcCcOC1ccC(Nc1CC1cOcc)Nc=c)NC1c)1N22))OCCcccccOcc=cC=cOccccC()=(NccCcNcO)1c1)CO=N)c)=ccc)COcccCccCcOcOcOC)ccC(ccOccc
# 3. ccOCcc1ccOO(NcCc(cccC)OOOccccCccc)cnC)c1Cc2c2CNc1O))cO)O1CcccCOcCccccNcCCC1)OOCCccONO=Occ)CccC1C=())c1cc)cC=(c)c1)cc1cc=cC1cC=2=OCcN1CO1cCc2nccCc)CCON
# 4. NOccO(O1cC2OCc))cO()c)OcC(11ONOc(Ccc2ONcO))CO()c2ccc(CcC=OccOccCCcn1CC1c)CCcCc2cOCCO2ccCc(c2ccC=cCcc(11cO=111c((222((c1cN)Cc1C)C2ncCcc=2=nlccc=O2ccc=O
# 5. cC=CNcO(OcN22ccCcccO1c(OCccOcCc1C)CccC11c=(cOcOc=(C)(c1cOc1)C=cCcc)cc1(OCCccc==12c=cOcc=cC)1COCcCNCcc2c1cc1CCc2cCcccCN1cC221c1cCNOc=(c)1)2ccOc12CcCCcc
# Valid samples:
# Epoch: 11, Batch: 0, Loss: 14941445120.0000
# [22:43:09] SMILES Parse Error: syntax error while parsing: ccCcCcccOcc1cC2c(ccnc2Oc1Cc=CONNcNC=CCcccccC1c(CccccOCC1c1ccCccnn(OCccc(c=cOcC(cOCCc=ccccn(=2c)cc=cncc(cccN=1CcC=CcnOOcc(cCcc1c)ccOccCccCcNCNcCccccCCc
# [22:43:09] SMILES Parse Error: check for mistakes around position 93:
# [22:43:09] c=cOcC(cOCCc=ccccn(=2c)cc=cncc(cccN=1CcC=
# [22:43:09] ~~~~~~~~~~~~~~~~~~~~^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES 'ccCcCcccOcc1cC2c(ccnc2Oc1Cc=CONNcNC=CCcccccC1c(CccccOCC1c1ccCccnn(OCccc(c=cOcC(cOCCc=ccccn(=2c)cc=cncc(cccN=1CcC=CcnOOcc(cCcc1c)ccOccCccCcNCNcCccccCCc' for input: 'ccCcCcccOcc1cC2c(ccnc2Oc1Cc=CONNcNC=CCcccccC1c(CccccOCC1c1ccCccnn(OCccc(c=cOcC(cOCCc=ccccn(=2c)cc=cncc(cccN=1CcC=CcnOOcc(cCcc1c)ccOccCccCcNCNcCccccCCc'
# [22:43:09] SMILES Parse Error: syntax error while parsing: )c)cn)1ccccccccOCcNc)CN)CcccNCcCccOcCcOC1ccC(Nc1CC1cOcc)Nc=c)NC1c)1N22))OCCcccccOcc=cC=cOccccC()=(NccCcNcO)1c1)CO=N)c)=ccc)COcccCccCcOcOcOC)ccC(ccOccc
# [22:43:09] SMILES Parse Error: check for mistakes around position 1:
# [22:43:09] )c)cn)1ccccccccOCcNc)CN)CcccNCcCccOcCcOC1
# [22:43:09] ^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES ')c)cn)1ccccccccOCcNc)CN)CcccNCcCccOcCcOC1ccC(Nc1CC1cOcc)Nc=c)NC1c)1N22))OCCcccccOcc=cC=cOccccC()=(NccCcNcO)1c1)CO=N)c)=ccc)COcccCccCcOcOcOC)ccC(ccOccc' for input: ')c)cn)1ccccccccOCcNc)CN)CcccNCcCccOcCcOC1ccC(Nc1CC1cOcc)Nc=c)NC1c)1N22))OCCcccccOcc=cC=cOccccC()=(NccCcNcO)1c1)CO=N)c)=ccc)COcccCccCcOcOcOC)ccC(ccOccc'
# [22:43:09] SMILES Parse Error: extra close parentheses while parsing: ccOCcc1ccOO(NcCc(cccC)OOOccccCccc)cnC)c1Cc2c2CNc1O))cO)O1CcccCOcCccccNcCCC1)OOCCccONO=Occ)CccC1C=())c1cc)cC=(c)c1)cc1cc=cC1cC=2=OCcN1CO1cCc2nccCc)CCON
# [22:43:09] SMILES Parse Error: check for mistakes around position 38:
# [22:43:09] cccC)OOOccccCccc)cnC)c1Cc2c2CNc1O))cO)O1C
# [22:43:09] ~~~~~~~~~~~~~~~~~~~~^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES 'ccOCcc1ccOO(NcCc(cccC)OOOccccCccc)cnC)c1Cc2c2CNc1O))cO)O1CcccCOcCccccNcCCC1)OOCCccONO=Occ)CccC1C=())c1cc)cC=(c)c1)cc1cc=cC1cC=2=OCcN1CO1cCc2nccCc)CCON' for input: 'ccOCcc1ccOO(NcCc(cccC)OOOccccCccc)cnC)c1Cc2c2CNc1O))cO)O1CcccCOcCccccNcCCC1)OOCCccONO=Occ)CccC1C=())c1cc)cC=(c)c1)cc1cc=cC1cC=2=OCcN1CO1cCc2nccCc)CCON'
# [22:43:09] SMILES Parse Error: extra close parentheses while parsing: NOccO(O1cC2OCc))cO()c)OcC(11ONOc(Ccc2ONcO))CO()c2ccc(CcC=OccOccCCcn1CC1c)CCcCc2cOCCO2ccCc(c2ccC=cCcc(11cO=111c((222((c1cN)Cc1C)C2ncCcc=2=nlccc=O2ccc=O
# [22:43:09] SMILES Parse Error: check for mistakes around position 16:
# [22:43:09] NOccO(O1cC2OCc))cO()c)OcC(11ONOc(Ccc2ONcO
# [22:43:09] ~~~~~~~~~~~~~~~^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES 'NOccO(O1cC2OCc))cO()c)OcC(11ONOc(Ccc2ONcO))CO()c2ccc(CcC=OccOccCCcn1CC1c)CCcCc2cOCCO2ccCc(c2ccC=cCcc(11cO=111c((222((c1cN)Cc1C)C2ncCcc=2=nlccc=O2ccc=O' for input: 'NOccO(O1cC2OCc))cO()c)OcC(11ONOc(Ccc2ONcO))CO()c2ccc(CcC=OccOccCCcn1CC1c)CCcCc2cOCCO2ccCc(c2ccC=cCcc(11cO=111c((222((c1cN)Cc1C)C2ncCcc=2=nlccc=O2ccc=O'
# [22:43:09] SMILES Parse Error: syntax error while parsing: cC=CNcO(OcN22ccCcccO1c(OCccOcCc1C)CccC11c=(cOcOc=(C)(c1cOc1)C=cCcc)cc1(OCCccc==12c=cOcc=cC)1COCcCNCcc2c1cc1CCc2cCcccCN1cC221c1cCNOc=(c)1)2ccOc12CcCCcc
# [22:43:09] SMILES Parse Error: check for mistakes around position 43:
# [22:43:09] (OCccOcCc1C)CccC11c=(cOcOc=(C)(c1cOc1)C=c
# [22:43:09] ~~~~~~~~~~~~~~~~~~~~^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES 'cC=CNcO(OcN22ccCcccO1c(OCccOcCc1C)CccC11c=(cOcOc=(C)(c1cOc1)C=cCcc)cc1(OCCccc==12c=cOcc=cC)1COCcCNCcc2c1cc1CCc2cCcccCN1cC221c1cCNOc=(c)1)2ccOc12CcCCcc' for input: 'cC=CNcO(OcN22ccCcccO1c(OCccOcCc1C)CccC11c=(cOcOc=(C)(c1cOc1)C=cCcc)cc1(OCCccc==12c=cOcc=cC)1COCcCNCcc2c1cc1CCc2cCcccCN1cC221c1cCNOc=(c)1)2ccOc12CcCCcc'
# [22:43:09] SMILES Parse Error: syntax error while parsing: )OOcCc1c=2cNOcO=c112NccCC=cCCNn1cc=ccccCnccc=cOOcCccccCcc)2COcO=(cOc=1ccC)1)Cc)c2COcc=Ncc1c1SC1OcOC)O(Cc=2c2O)CC=CcO2cN)NcOC=(On)ccO=OOC2=Oc(cO)cOccc)
# [22:43:09] SMILES Parse Error: check for mistakes around position 1:
# [22:43:09] )OOcCc1c=2cNOcO=c112NccCC=cCCNn1cc=ccccCn
# [22:43:09] ^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES ')OOcCc1c=2cNOcO=c112NccCC=cCCNn1cc=ccccCnccc=cOOcCccccCcc)2COcO=(cOc=1ccC)1)Cc)c2COcc=Ncc1c1SC1OcOC)O(Cc=2c2O)CC=CcO2cN)NcOC=(On)ccO=OOC2=Oc(cO)cOccc)' for input: ')OOcCc1c=2cNOcO=c112NccCC=cCCNn1cc=ccccCnccc=cOOcCccccCcc)2COcO=(cOc=1ccC)1)Cc)c2COcc=Ncc1c1SC1OcOC)O(Cc=2c2O)CC=CcO2cN)NcOC=(On)ccO=OOC2=Oc(cO)cOccc)'
# [22:43:09] SMILES Parse Error: syntax error while parsing: ==cccCCNcccNccCcccCcc)=)cOcO11=cO1nC(OcccccO1cc1c()c)Oc)cCcc2cCccCcccCcCCOcccCnc1cc)Nc(COlCc1O1=)OccCOOcccCc)=ccc1cCCCcO2cNcONcccOCccOOcccc2ccNNcCCccC
# [22:43:09] SMILES Parse Error: check for mistakes around position 1:
# [22:43:09] ==cccCCNcccNccCcccCcc)=)cOcO11=cO1nC(Occc
# [22:43:09] ^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES '==cccCCNcccNccCcccCcc)=)cOcO11=cO1nC(OcccccO1cc1c()c)Oc)cCcc2cCccCcccCcCCOcccCnc1cc)Nc(COlCc1O1=)OccCOOcccCc)=ccc1cCCCcO2cNcONcccOCccOOcccc2ccNNcCCccC' for input: '==cccCCNcccNccCcccCcc)=)cOcO11=cO1nC(OcccccO1cc1c()c)Oc)cCcc2cCccCcccCcCCOcccCnc1cc)Nc(COlCc1O1=)OccCOOcccCc)=ccc1cCCCcO2cNcONcccOCccOOcccc2ccNNcCCccC'
# [22:43:09] SMILES Parse Error: syntax error while parsing: (cCcCcc)cOccc)cc)COC(ccCNcCcCCCc=cC)cc1Oc(OCc=1)cccC2Occccc(1CO==OcN2CCcCCC2ccccccOO1cOOC)(cC)c(ccccccc1OnccCC1O)ccC=cC1cC)CCN=)OcO2CcOcOccCOOcCcC)C(=
# [22:43:09] SMILES Parse Error: check for mistakes around position 1:
# [22:43:09] (cCcCcc)cOccc)cc)COC(ccCNcCcCCCc=cC)cc1Oc
# [22:43:09] ^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES '(cCcCcc)cOccc)cc)COC(ccCNcCcCCCc=cC)cc1Oc(OCc=1)cccC2Occccc(1CO==OcN2CCcCCC2ccccccOO1cOOC)(cC)c(ccccccc1OnccCC1O)ccC=cC1cC)CCN=)OcO2CcOcOccCOOcCcC)C(=' for input: '(cCcCcc)cOccc)cc)COC(ccCNcCcCCCc=cC)cc1Oc(OCc=1)cccC2Occccc(1CO==OcN2CCcCCC2ccccccOO1cOOC)(cC)c(ccccccc1OnccCC1O)ccC=cC1cC)CCN=)OcO2CcOcOccCOOcCcC)C(='
# [22:43:09] SMILES Parse Error: syntax error while parsing: 1C2cCO)c1cOccc22OO1Occ)OcCcccO1cCcccC1CNcC)cCO2=c(=-cCcOOCcNcNcc)ccccCccc11cC1ccO=cc1=)cCO(N=Occ)()cOcCcNO=)c2cc(c))c2Occcc1OC=NOcn)nCcCccc(cCO=C-cccc
# [22:43:09] SMILES Parse Error: check for mistakes around position 1:
# [22:43:09] 1C2cCO)c1cOccc22OO1Occ)OcCcccO1cCcccC1CNc
# [22:43:09] ^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES '1C2cCO)c1cOccc22OO1Occ)OcCcccO1cCcccC1CNcC)cCO2=c(=-cCcOOCcNcNcc)ccccCccc11cC1ccO=cc1=)cCO(N=Occ)()cOcCcNO=)c2cc(c))c2Occcc1OC=NOcn)nCcCccc(cCO=C-cccc' for input: '1C2cCO)c1cOccc22OO1Occ)OcCcccO1cCcccC1CNcC)cCO2=c(=-cCcOOCcNcNcc)ccccCccc11cC1ccO=cc1=)cCO(N=Occ)()cOcCcNO=)c2cc(c))c2Occcc1OC=NOcn)nCcCccc(cCO=C-cccc'
# [22:43:09] SMILES Parse Error: extra close parentheses while parsing: cCN)COCNcCCccCCCC(O)COc)Oc)OOOcCNNOcCcc=(cCCccccc()(O(cccccCccccOCcCcc1O1=OOcOCO21CN(cOC)c=)C)(CcC1CccOcc=c=CO11CC(cccccccC)(cCCc=C)cccO1c1CcOcCccc2cc
# [22:43:09] SMILES Parse Error: check for mistakes around position 4:
# [22:43:09] cCN)COCNcCCccCCCC(O)COc)Oc)OOOcCNNOcCcc=(
# [22:43:09] ~~~^
# [22:43:09] SMILES Parse Error: Failed parsing SMILES 'cCN)COCNcCCccCCCC(O)COc)Oc)OOOcCNNOcCcc=(cCCccccc()(O(cccccCccccOCcCcc1O1=OOcOCO21CN(cOC)c=)C)(CcC1CccOcc=c=CO11CC(cccccccC)(cCCc=C)cccO1c1CcOcCccc2cc' for input: 'cCN)COCNcCCccCCCC(O)COc)Oc)OOOcCNNOcCcc=(cCCccccc()(O(cccccCccccOCcCcc1O1=OOcOCO21CN(cOC)c=)C)(CcC1CccOcc=c=CO11CC(cccccccC)(cCCc=C)cccO1c1CcOcCccc2cc'
# Epoch: 11, Batch: 10, Loss: -18200.0859
# Epoch: 11, Batch: 20, Loss: 21676597248.0000
# Epoch: 11, Batch: 30, Loss: 6255233024.0000
# Epoch: 11, Batch: 40, Loss: 5135295488.0000
# Epoch: 11, Batch: 50, Loss: 282131529728.0000
# Epoch: 11, Batch: 60, Loss: 38589431808.0000
# Epoch: 11, Batch: 70, Loss: 97855070208.0000
# Epoch: 11, Batch: 80, Loss: 21473742848.0000
# Epoch 11, Average loss: 39793142267.0006
# Epoch: 12, Batch: 0, Loss: 45359247360.0000
# Epoch: 12, Batch: 10, Loss: 42369036288.0000
# Epoch: 12, Batch: 20, Loss: 19987425280.0000
# Epoch: 12, Batch: 30, Loss: 29773703168.0000
# Epoch: 12, Batch: 40, Loss: 58672726016.0000
# Epoch: 12, Batch: 50, Loss: 18969118720.0000
# Epoch: 12, Batch: 60, Loss: 51889389568.0000
# Epoch: 12, Batch: 70, Loss: 42449203200.0000
# Epoch: 12, Batch: 80, Loss: 18761469952.0000
# Epoch 12, Average loss: 42089252436.4655
# Epoch: 13, Batch: 0, Loss: 9414069248.0000
# Epoch: 13, Batch: 10, Loss: 30047248384.0000
# Epoch: 13, Batch: 20, Loss: 27926882304.0000
# Epoch: 13, Batch: 30, Loss: 6332071936.0000
# Epoch: 13, Batch: 40, Loss: 108215230464.0000
# Epoch: 13, Batch: 50, Loss: -16099.3770
# Epoch: 13, Batch: 60, Loss: 102396100608.0000
# Epoch: 13, Batch: 70, Loss: 5048040448.0000
# Epoch: 13, Batch: 80, Loss: 20663519232.0000
# Epoch 13, Average loss: 30364480734.8493
# Epoch: 14, Batch: 0, Loss: 14183304192.0000
# Epoch: 14, Batch: 10, Loss: 22897551360.0000
# Epoch: 14, Batch: 20, Loss: 76004950016.0000
# Epoch: 14, Batch: 30, Loss: 3362402304.0000
# Epoch: 14, Batch: 40, Loss: 3186684672.0000
# Epoch: 14, Batch: 50, Loss: 19811125248.0000
# Epoch: 14, Batch: 60, Loss: 38177640448.0000
# Epoch: 14, Batch: 70, Loss: 54045151232.0000
# Epoch: 14, Batch: 80, Loss: 18731071488.0000
# Epoch 14, Average loss: 25627583647.4126
# Epoch: 15, Batch: 0, Loss: 31697428480.0000
# Epoch: 15, Batch: 10, Loss: -15628.0293
# Epoch: 15, Batch: 20, Loss: 3186952192.0000
# Epoch: 15, Batch: 30, Loss: 13484550144.0000
# Epoch: 15, Batch: 40, Loss: 38819749888.0000
# Epoch: 15, Batch: 50, Loss: -20495.7773
# Epoch: 15, Batch: 60, Loss: 44990984192.0000
# Epoch: 15, Batch: 70, Loss: 15578054656.0000
# Epoch: 15, Batch: 80, Loss: -17909.8340
# Epoch 15, Average loss: 25819076656.5250
# Epoch: 16, Batch: 0, Loss: 10621603840.0000
# Epoch: 16, Batch: 10, Loss: 2527031296.0000
# Epoch: 16, Batch: 20, Loss: 33731540992.0000
# Epoch: 16, Batch: 30, Loss: 2224112896.0000
# Epoch: 16, Batch: 40, Loss: 27439568896.0000
# Epoch: 16, Batch: 50, Loss: 5404862464.0000
# Epoch: 16, Batch: 60, Loss: 15064712192.0000
# Epoch: 16, Batch: 70, Loss: 2590913792.0000
# Epoch: 16, Batch: 80, Loss: -13976.0312
# Epoch 16, Average loss: 16902062868.7112
# Epoch: 17, Batch: 0, Loss: 2123748992.0000
# Epoch: 17, Batch: 10, Loss: -15165.7969
# Epoch: 17, Batch: 20, Loss: 18393987072.0000
# Epoch: 17, Batch: 30, Loss: 34854739968.0000
# Epoch: 17, Batch: 40, Loss: 71660265472.0000
# Epoch: 17, Batch: 50, Loss: 58119323648.0000
# Epoch: 17, Batch: 60, Loss: 6358166528.0000
# Epoch: 17, Batch: 70, Loss: 7564001280.0000
# Epoch: 17, Batch: 80, Loss: 20347123712.0000
# Epoch 17, Average loss: 17270861358.0473
# Epoch: 18, Batch: 0, Loss: 1817031552.0000
# Epoch: 18, Batch: 10, Loss: -10454.3340
# Epoch: 18, Batch: 20, Loss: 8908356608.0000
# Epoch: 18, Batch: 30, Loss: 43914256384.0000
# Epoch: 18, Batch: 40, Loss: 8448467968.0000
# Epoch: 18, Batch: 50, Loss: 1588631808.0000
# Epoch: 18, Batch: 60, Loss: -11597.8438
# Epoch: 18, Batch: 70, Loss: 4605538816.0000
# Epoch: 18, Batch: 80, Loss: 1426996992.0000
# Epoch 18, Average loss: 8350355838.7609
# Epoch: 19, Batch: 0, Loss: 31383205888.0000
# Epoch: 19, Batch: 10, Loss: -16032.8652
# Epoch: 19, Batch: 20, Loss: -13180.9375
# Epoch: 19, Batch: 30, Loss: -15158.7500
# Epoch: 19, Batch: 40, Loss: -20096.4648
# Epoch: 19, Batch: 50, Loss: 28121456640.0000
# Epoch: 19, Batch: 60, Loss: 89993043968.0000
# Epoch: 19, Batch: 70, Loss: 103457800192.0000
# Epoch: 19, Batch: 80, Loss: 8244002816.0000
# Epoch 19, Average loss: 39158419150.4674
# Epoch: 20, Batch: 0, Loss: 19820472320.0000
# Epoch: 20, Batch: 10, Loss: 42238480384.0000
# Epoch: 20, Batch: 20, Loss: 3695513088.0000
# Epoch: 20, Batch: 30, Loss: 27739654144.0000
# Epoch: 20, Batch: 40, Loss: -7578.1621
# Epoch: 20, Batch: 50, Loss: 18629263360.0000
# Epoch: 20, Batch: 60, Loss: 18134415360.0000
# Epoch: 20, Batch: 70, Loss: 2233086208.0000
# Epoch: 20, Batch: 80, Loss: 9419984896.0000
# Epoch 20, Average loss: 16755087235.0036
# [22:43:27] SMILES Parse Error: syntax error while parsing: =Oc)c)ccCC)OccOCOccc)OCCCc=OcOcc=CC1Oc)=cOcccC)cc)c))cccccnccccc=c)ccCCcc=c1ccCcC)()Occ(c3C)OcOcOC(1)cC)OCCccccNcO)cOc)Cc)cOc2)HOcO=ON1)Nc3OCNCccccC)O
# [22:43:27] SMILES Parse Error: check for mistakes around position 1:
# [22:43:27] =Oc)c)ccCC)OccOCOccc)OCCCc=OcOcc=CC1Oc)=c
# [22:43:27] ^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES '=Oc)c)ccCC)OccOCOccc)OCCCc=OcOcc=CC1Oc)=cOcccC)cc)c))cccccnccccc=c)ccCCcc=c1ccCcC)()Occ(c3C)OcOcOC(1)cC)OCCccccNcO)cOc)Cc)cOc2)HOcO=ON1)Nc3OCNCccccC)O' for input: '=Oc)c)ccCC)OccOCOccc)OCCCc=OcOcc=CC1Oc)=cOcccC)cc)c))cccccnccccc=c)ccCCcc=c1ccCcC)()Occ(c3C)OcOcOC(1)cC)OCCccccNcO)cOc)Cc)cOc2)HOcO=ON1)Nc3OCNCccccC)O'
# [22:43:27] SMILES Parse Error: syntax error while parsing: )c)Oc)c)CcO=ccC(cCccOcc1cccONOCnc1)2OccOCccO1cc1C=cc))C))Occcnc(cOccOcCnOccc3O=Ncc)=cC2CC=)11Oc)c)ccccO)c1O)Oc1n)OCO)2O=NOCOcN)cONON1cc)OcCcOc)ccN)ccc
# [22:43:27] SMILES Parse Error: check for mistakes around position 1:
# [22:43:27] )c)Oc)c)CcO=ccC(cCccOcc1cccONOCnc1)2OccOC
# [22:43:27] ^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES ')c)Oc)c)CcO=ccC(cCccOcc1cccONOCnc1)2OccOCccO1cc1C=cc))C))Occcnc(cOccOcCnOccc3O=Ncc)=cC2CC=)11Oc)c)ccccO)c1O)Oc1n)OCO)2O=NOCOcN)cONON1cc)OcCcOc)ccN)ccc' for input: ')c)Oc)c)CcO=ccC(cCccOcc1cccONOCnc1)2OccOCccO1cc1C=cc))C))Occcnc(cOccOcCnOccc3O=Ncc)=cC2CC=)11Oc)c)ccccO)c1O)Oc1n)OCO)2O=NOCOcN)cONON1cc)OcCcOc)ccN)ccc'
# [22:43:27] SMILES Parse Error: extra close parentheses while parsing: cccOc11))O)C1OOcc)cO)=C)c1cO)CcOcccO(O)O))ccccO1Occ1OOc)Cc)CcccOCc1NO)1Cc)cOC))2OOcOccON)1c2)cccCOc)c)Nc)cCCCOCOc1)()N(CCOSc1ccOOOcO)O))c1Ncc)2ccOO1Cc
# [22:43:27] SMILES Parse Error: check for mistakes around position 8:
# [22:43:27] cccOc11))O)C1OOcc)cO)=C)c1cO)CcOcccO(O)O)
# [22:43:27] ~~~~~~~^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES 'cccOc11))O)C1OOcc)cO)=C)c1cO)CcOcccO(O)O))ccccO1Occ1OOc)Cc)CcccOCc1NO)1Cc)cOC))2OOcOccON)1c2)cccCOc)c)Nc)cCCCOCOc1)()N(CCOSc1ccOOOcO)O))c1Ncc)2ccOO1Cc' for input: 'cccOc11))O)C1OOcc)cO)=C)c1cO)CcOcccO(O)O))ccccO1Occ1OOc)Cc)CcccOCc1NO)1Cc)cOC))2OOcOccON)1c2)cccCOc)c)Nc)cCCCOCOc1)()N(CCOSc1ccOOOcO)O))c1Ncc)2ccOO1Cc'
# [22:43:27] SMILES Parse Error: syntax error while parsing: Ccc=COC1c(C1cCccC)Ncc=1(Oc1O1NONOcNn)cOcccccC==OCCC112)cc)ccCNNCcc)Occccc))Oc()c1c)C(cc1CNc11COO1O)cc(1Occ(ccNccN(11CccC))cccccccHCNNcCOOc)c(O(c1ccc1C
# [22:43:27] SMILES Parse Error: check for mistakes around position 47:
# [22:43:27] 1O1NONOcNn)cOcccccC==OCCC112)cc)ccCNNCcc)
# [22:43:27] ~~~~~~~~~~~~~~~~~~~~^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES 'Ccc=COC1c(C1cCccC)Ncc=1(Oc1O1NONOcNn)cOcccccC==OCCC112)cc)ccCNNCcc)Occccc))Oc()c1c)C(cc1CNc11COO1O)cc(1Occ(ccNccN(11CccC))cccccccHCNNcCOOc)c(O(c1ccc1C' for input: 'Ccc=COC1c(C1cCccC)Ncc=1(Oc1O1NONOcNn)cOcccccC==OCCC112)cc)ccCNNCcc)Occccc))Oc()c1c)C(cc1CNc11COO1O)cc(1Occ(ccNccN(11CccC))cccccccHCNNcCOOc)c(O(c1ccc1C'
# [22:43:27] SMILES Parse Error: extra close parentheses while parsing: c1cOc)COO=1=2(ccC=cccOcCccccc1c1cCcc=c)(cC1()cCc=cC))OO(c))1OcCccOnN)cc)N1O)CC)C=)Ccc))c(c)=Cc)cc)O)cCCCC)c1ccCCcc)c(=))ccc)()c=)O2N(NcO))cc1N(cOnOO)C
# [22:43:27] SMILES Parse Error: check for mistakes around position 6:
# [22:43:27] c1cOc)COO=1=2(ccC=cccOcCccccc1c1cCcc=c)(c
# [22:43:27] ~~~~~^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES 'c1cOc)COO=1=2(ccC=cccOcCccccc1c1cCcc=c)(cC1()cCc=cC))OO(c))1OcCccOnN)cc)N1O)CC)C=)Ccc))c(c)=Cc)cc)O)cCCCC)c1ccCCcc)c(=))ccc)()c=)O2N(NcO))cc1N(cOnOO)C' for input: 'c1cOc)COO=1=2(ccC=cccOcCccccc1c1cCcc=c)(cC1()cCc=cC))OO(c))1OcCccOnN)cc)N1O)CC)C=)Ccc))c(c)=Cc)cc)O)cCCCC)c1ccCCcc)c(=))ccc)()c=)O2N(NcO))cc1N(cOnOO)C'
# [22:43:27] SMILES Parse Error: extra close parentheses while parsing: ccc)c11cO=cOcc=cOcc1cc1(CC)Occ-cCcOOO(()1c(cOc1=(SO)ccC)1)c)ccOcO1c(ccccc)OCccCcOCO)cOCcOccHSO)c1cc)cccOOcCc=O)cccc(OncSOcccSc)=C))cCOcO)O)1ccc=ccCnCN
# [22:43:27] SMILES Parse Error: check for mistakes around position 4:
# [22:43:27] ccc)c11cO=cOcc=cOcc1cc1(CC)Occ-cCcOOO(()1
# [22:43:27] ~~~^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES 'ccc)c11cO=cOcc=cOcc1cc1(CC)Occ-cCcOOO(()1c(cOc1=(SO)ccC)1)c)ccOcO1c(ccccc)OCccCcOCO)cOCcOccHSO)c1cc)cccOOcCc=O)cccc(OncSOcccSc)=C))cCOcO)O)1ccc=ccCnCN' for input: 'ccc)c11cO=cOcc=cOcc1cc1(CC)Occ-cCcOOO(()1c(cOc1=(SO)ccC)1)c)ccOcO1c(ccccc)OCccCcOCO)cOCcOccHSO)c1cc)cccOOcCc=O)cccc(OncSOcccSc)=C))cCOcO)O)1ccc=ccCnCN'
# [22:43:27] SMILES Parse Error: syntax error while parsing: 2c)2OCcNOOOccccC)cCCc=O)CCc)(cCnccc1cccOc1=)=c1cCcCCC)(CccOc)c)OcccO1c)OcCccCOOCcCF))))cOOccccC(OO))c1lc=NCN2cl)cc2ccO()(cOc1cOCS)OCcc))ccccNcOcccc)1c
# [22:43:27] SMILES Parse Error: check for mistakes around position 1:
# [22:43:27] 2c)2OCcNOOOccccC)cCCc=O)CCc)(cCnccc1cccOc
# [22:43:27] ^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES '2c)2OCcNOOOccccC)cCCc=O)CCc)(cCnccc1cccOc1=)=c1cCcCCC)(CccOc)c)OcccO1c)OcCccCOOCcCF))))cOOccccC(OO))c1lc=NCN2cl)cc2ccO()(cOc1cOCS)OCcc))ccccNcOcccc)1c' for input: '2c)2OCcNOOOccccC)cCCc=O)CCc)(cCnccc1cccOc1=)=c1cCcCCC)(CccOc)c)OcccO1c)OcCccCOOCcCF))))cOOccccC(OO))c1lc=NCN2cl)cc2ccO()(cOc1cOCS)OCcc))ccccNcOcccc)1c'
# [22:43:27] SMILES Parse Error: extra close parentheses while parsing: c=OO)c)ccc1Cr1ccCcccO)OOCO1Cc2c)c)cccCcccCCCCc)O11c=1OCOC)=cc1n1ccNCO=c)cccONOc)=ccccOcccCNO())cCO)CCc=)c1CCcOc)C))CCc1ON1cOOCOOcO1)cO1C1)c=cCccCOc)NO
# [22:43:27] SMILES Parse Error: check for mistakes around position 5:
# [22:43:27] c=OO)c)ccc1Cr1ccCcccO)OOCO1Cc2c)c)cccCccc
# [22:43:27] ~~~~^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES 'c=OO)c)ccc1Cr1ccCcccO)OOCO1Cc2c)c)cccCcccCCCCc)O11c=1OCOC)=cc1n1ccNCO=c)cccONOc)=ccccOcccCNO())cCO)CCc=)c1CCcOc)C))CCc1ON1cOOCOOcO1)cO1C1)c=cCccCOc)NO' for input: 'c=OO)c)ccc1Cr1ccCcccO)OOCO1Cc2c)c)cccCcccCCCCc)O11c=1OCOC)=cc1n1ccNCO=c)cccONOc)=ccccOcccCNO())cCO)CCc=)c1CCcOc)C))CCc1ON1cOOCOOcO1)cO1C1)c=cCccCOc)NO'
# [22:43:27] SMILES Parse Error: extra close parentheses while parsing: cC)OCC)Cc(OOOc1Oc)OcONcC=cccNc1C=)cC)cOc)CcOcCOcc()COccOc1ccOcCOcNCCCO=cOcc2cCcOc1ccccSOOcc=cCcO))COc1c))cC1cc)ccc)O)CcO(OC)C)ccOccc=O)1OO)=Cc(cc=Cc)c
# [22:43:27] SMILES Parse Error: check for mistakes around position 3:
# [22:43:27] cC)OCC)Cc(OOOc1Oc)OcONcC=cccNc1C=)cC)cOc)
# [22:43:27] ~~^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES 'cC)OCC)Cc(OOOc1Oc)OcONcC=cccNc1C=)cC)cOc)CcOcCOcc()COccOc1ccOcCOcNCCCO=cOcc2cCcOc1ccccSOOcc=cCcO))COc1c))cC1cc)ccc)O)CcO(OC)C)ccOccc=O)1OO)=Cc(cc=Cc)c' for input: 'cC)OCC)Cc(OOOc1Oc)OcONcC=cccNc1C=)cC)cOc)CcOcCOcc()COccOc1ccOcCOcNCCCO=cOcc2cCcOc1ccccSOOcc=cCcO))COc1c))cC1cc)ccc)O)CcO(OC)C)ccOccc=O)1OO)=Cc(cc=Cc)c'
# [22:43:27] SMILES Parse Error: syntax error while parsing: )Oc(ONC)C=cc1cc1cccO)O)Oc1=C1cO)cncc)O)1cc2()cCC=cccc=1cc)ccc1l)NcOc)c)=)c))c)Occ()cO)ccc2ccC))ccc11cOcc(Occc=Ccccc)cc(cOC)OcO)C))cCO)1ONc)Oc1c=Cc)O)N
# [22:43:27] SMILES Parse Error: check for mistakes around position 1:
# [22:43:27] )Oc(ONC)C=cc1cc1cccO)O)Oc1=C1cO)cncc)O)1c
# [22:43:27] ^
# [22:43:27] SMILES Parse Error: Failed parsing SMILES ')Oc(ONC)C=cc1cc1cccO)O)Oc1=C1cO)cncc)O)1cc2()cCC=cccc=1cc)ccc1l)NcOc)c)=)c))c)Occ()cO)ccc2ccC))ccc11cOcc(Occc=Ccccc)cc(cOC)OcO)C))cCO)1ONc)Oc1c=Cc)O)N' for input: ')Oc(ONC)C=cc1cc1cccO)O)Oc1=C1cO)cncc)O)1cc2()cCC=cccc=1cc)ccc1l)NcOc)c)=)c))c)Occ()cO)ccc2ccC))ccc11cOcc(Occc=Ccccc)cc(cOC)OcO)C))cCO)1ONc)Oc1c=Cc)O)N'
# Generated samples (validity rate: 0.00%):
# 1. =Oc)c)ccCC)OccOCOccc)OCCCc=OcOcc=CC1Oc)=cOcccC)cc)c))cccccnccccc=c)ccCCcc=c1ccCcC)()Occ(c3C)OcOcOC(1)cC)OCCccccNcO)cOc)Cc)cOc2)HOcO=ON1)Nc3OCNCccccC)O
# 2. )c)Oc)c)CcO=ccC(cCccOcc1cccONOCnc1)2OccOCccO1cc1C=cc))C))Occcnc(cOccOcCnOccc3O=Ncc)=cC2CC=)11Oc)c)ccccO)c1O)Oc1n)OCO)2O=NOCOcN)cONON1cc)OcCcOc)ccN)ccc
# 3. cccOc11))O)C1OOcc)cO)=C)c1cO)CcOcccO(O)O))ccccO1Occ1OOc)Cc)CcccOCc1NO)1Cc)cOC))2OOcOccON)1c2)cccCOc)c)Nc)cCCCOCOc1)()N(CCOSc1ccOOOcO)O))c1Ncc)2ccOO1Cc
# 4. Ccc=COC1c(C1cCccC)Ncc=1(Oc1O1NONOcNn)cOcccccC==OCCC112)cc)ccCNNCcc)Occccc))Oc()c1c)C(cc1CNc11COO1O)cc(1Occ(ccNccN(11CccC))cccccccHCNNcCOOc)c(O(c1ccc1C
# 5. c1cOc)COO=1=2(ccC=cccOcCccccc1c1cCcc=c)(cC1()cCc=cC))OO(c))1OcCccOnN)cc)N1O)CC)C=)Ccc))c(c)=Cc)cc)O)cCCCC)c1ccCCcc)c(=))ccc)()c=)O2N(NcO))cc1N(cOnOO)C
# Valid samples:
# Epoch: 21, Batch: 0, Loss: -18009.6016
# Epoch: 21, Batch: 10, Loss: 34166409216.0000
# Epoch: 21, Batch: 20, Loss: 37573099520.0000
# Epoch: 21, Batch: 30, Loss: -16809.5859
# Epoch: 21, Batch: 40, Loss: -16521.9766
# Epoch: 21, Batch: 50, Loss: -17147.5762
# Epoch: 21, Batch: 60, Loss: 3448197888.0000
# Epoch: 21, Batch: 70, Loss: 7022996992.0000
# Epoch: 21, Batch: 80, Loss: 18226814976.0000
# Epoch 21, Average loss: 12984220789.1451
# Epoch: 22, Batch: 0, Loss: 1599071616.0000
# Epoch: 22, Batch: 10, Loss: 1568824576.0000
# Epoch: 22, Batch: 20, Loss: 6357597184.0000
# Epoch: 22, Batch: 30, Loss: 5975561728.0000
# Epoch: 22, Batch: 40, Loss: -17622.1523
# Epoch: 22, Batch: 50, Loss: 6707800576.0000
# Epoch: 22, Batch: 60, Loss: 6504795648.0000
# Epoch: 22, Batch: 70, Loss: 3818852608.0000
# Epoch: 22, Batch: 80, Loss: -17565.1289
# Epoch 22, Average loss: 6945463638.8901
# Epoch: 23, Batch: 0, Loss: 7133132800.0000
# Epoch: 23, Batch: 10, Loss: -11157.0801
# Epoch: 23, Batch: 20, Loss: -12218.0840
# Epoch: 23, Batch: 30, Loss: 23347826688.0000
# Epoch: 23, Batch: 40, Loss: 587953537024.0000
# Epoch: 23, Batch: 50, Loss: 8442449920.0000
# Epoch: 23, Batch: 60, Loss: 24603774976.0000
# Epoch: 23, Batch: 70, Loss: 3926740736.0000
# Epoch: 23, Batch: 80, Loss: -16767.2852
# Epoch 23, Average loss: 85689028675.1315
# Epoch: 24, Batch: 0, Loss: 15217319936.0000
# Epoch: 24, Batch: 10, Loss: 37540147200.0000
# Epoch: 24, Batch: 20, Loss: -19866.1250
# Epoch: 24, Batch: 30, Loss: 5019809792.0000
# Epoch: 24, Batch: 40, Loss: 303105048576.0000
# Epoch: 24, Batch: 50, Loss: 2826844928.0000
# Epoch: 24, Batch: 60, Loss: 2401433344.0000
# Epoch: 24, Batch: 70, Loss: -19446.9121
# Epoch: 24, Batch: 80, Loss: 136378155008.0000
# Epoch 24, Average loss: 28484189581.4688
# Epoch: 25, Batch: 0, Loss: 3134662656.0000
# Epoch: 25, Batch: 10, Loss: 5707959296.0000
# Epoch: 25, Batch: 20, Loss: 3746066688.0000
# Epoch: 25, Batch: 30, Loss: 5071667712.0000
# Epoch: 25, Batch: 40, Loss: 6455406592.0000
# Epoch: 25, Batch: 50, Loss: 4980557312.0000
# Epoch: 25, Batch: 60, Loss: -20988.3281
# Epoch: 25, Batch: 70, Loss: 12104503296.0000
# Epoch: 25, Batch: 80, Loss: 1156376832.0000
# Epoch 25, Average loss: 13797189196.6458
# Epoch: 26, Batch: 0, Loss: 2983196672.0000
# Epoch: 26, Batch: 10, Loss: 51333865472.0000
# Epoch: 26, Batch: 20, Loss: 3698281984.0000
# Epoch: 26, Batch: 30, Loss: 18872123392.0000
# Epoch: 26, Batch: 40, Loss: 103530700800.0000
# Epoch: 26, Batch: 50, Loss: 30117838848.0000
# Epoch: 26, Batch: 60, Loss: 5678362624.0000
# Epoch: 26, Batch: 70, Loss: -21844.3828
# Epoch: 26, Batch: 80, Loss: -21561.6855
# Epoch 26, Average loss: 20649746987.9762
# Epoch: 27, Batch: 0, Loss: 20924571648.0000
# Epoch: 27, Batch: 10, Loss: 15525258240.0000
# Epoch: 27, Batch: 20, Loss: 3386829312.0000
# Epoch: 27, Batch: 30, Loss: 2899691776.0000
# Epoch: 27, Batch: 40, Loss: 5911685632.0000
# Epoch: 27, Batch: 50, Loss: 1250090752.0000
# Epoch: 27, Batch: 60, Loss: 1206236672.0000
# Epoch: 27, Batch: 70, Loss: 1158656000.0000
# Epoch: 27, Batch: 80, Loss: 3804497152.0000
# Epoch 27, Average loss: 12020353882.0209
# Epoch: 28, Batch: 0, Loss: -19039.6152
# Epoch: 28, Batch: 10, Loss: 2809976832.0000
# Epoch: 28, Batch: 20, Loss: 3342190080.0000
# Epoch: 28, Batch: 30, Loss: 47932874752.0000
# Epoch: 28, Batch: 40, Loss: 3171653632.0000
# Epoch: 28, Batch: 50, Loss: 2751517184.0000
# Epoch: 28, Batch: 60, Loss: 6592040448.0000
# Epoch: 28, Batch: 70, Loss: 8202585600.0000
# Epoch: 28, Batch: 80, Loss: 43396136960.0000
# Epoch 28, Average loss: 7642299670.8787
# Epoch: 29, Batch: 0, Loss: 5760828928.0000
# Epoch: 29, Batch: 10, Loss: 2662139392.0000
# Epoch: 29, Batch: 20, Loss: 18212904960.0000
# Epoch: 29, Batch: 30, Loss: -20329.4297
# Epoch: 29, Batch: 40, Loss: 18912626688.0000
# Epoch: 29, Batch: 50, Loss: -21007.5469
# Epoch: 29, Batch: 60, Loss: 2273292544.0000
# Epoch: 29, Batch: 70, Loss: 3287524096.0000
# Epoch: 29, Batch: 80, Loss: 1308092928.0000
# Epoch 29, Average loss: 11874236234.7398
# Epoch: 30, Batch: 0, Loss: 1368887168.0000
# Epoch: 30, Batch: 10, Loss: 5671672320.0000
# Epoch: 30, Batch: 20, Loss: 2165047040.0000
# Epoch: 30, Batch: 30, Loss: 4086479104.0000
# Epoch: 30, Batch: 40, Loss: 2246048512.0000
# Epoch: 30, Batch: 50, Loss: 938992128.0000
# Epoch: 30, Batch: 60, Loss: 5899127296.0000
# Epoch: 30, Batch: 70, Loss: 1692825472.0000
# Epoch: 30, Batch: 80, Loss: 7249884672.0000
# Epoch 30, Average loss: 7795964708.5856
# [22:43:45] SMILES Parse Error: extra close parentheses while parsing: c)CCc2O((1cCcc((c)ccO1)cccc=O))Oc=[OCc)1c((CCcCc2ONc1)C(c)C)C(2c=cccc2OCN))NcOcc2OcC)cCcCcc2ccc=O2cc=c2CC2cCOc(2cO)1O12c)1)C)=c1))ncc1)c)O)ccCcCCcN)NN
# [22:43:45] SMILES Parse Error: check for mistakes around position 2:
# [22:43:45] c)CCc2O((1cCcc((c)ccO1)cccc=O))Oc=[OCc)1c
# [22:43:45] ~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'c)CCc2O((1cCcc((c)ccO1)cccc=O))Oc=[OCc)1c((CCcCc2ONc1)C(c)C)C(2c=cccc2OCN))NcOcc2OcC)cCcCcc2ccc=O2cc=c2CC2cCOc(2cO)1O12c)1)C)=c1))ncc1)c)O)ccCcCCcN)NN' for input: 'c)CCc2O((1cCcc((c)ccO1)cccc=O))Oc=[OCc)1c((CCcCc2ONc1)C(c)C)C(2c=cccc2OCN))NcOcc2OcC)cCcCcc2ccc=O2cc=c2CC2cCOc(2cO)1O12c)1)C)=c1))ncc1)c)O)ccCcCCcN)NN'
# [22:43:45] SMILES Parse Error: syntax error while parsing: cNOcCN1CccOc=-Cc(NccccCncCcC)ccccCOC2CccOc2OCc11cccc2)cncOc=Cc=c(CScOCOC))O))c))Cc1N(cCcOcN[cH=((cCNN)O)c=2(C)cc=c)c11cOCOc21OcccFOcCCNN)O1cc(c2OcCcO=
# [22:43:45] SMILES Parse Error: check for mistakes around position 14:
# [22:43:45] cNOcCN1CccOc=-Cc(NccccCncCcC)ccccCOC2CccO
# [22:43:45] ~~~~~~~~~~~~~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'cNOcCN1CccOc=-Cc(NccccCncCcC)ccccCOC2CccOc2OCc11cccc2)cncOc=Cc=c(CScOCOC))O))c))Cc1N(cCcOcN[cH=((cCNN)O)c=2(C)cc=c)c11cOCOc21OcccFOcCCNN)O1cc(c2OcCcO=' for input: 'cNOcCN1CccOc=-Cc(NccccCncCcC)ccccCOC2CccOc2OCc11cccc2)cncOc=Cc=c(CScOCOC))O))c))Cc1N(cCcOcN[cH=((cCNN)O)c=2(C)cc=c)c11cOCOc21OcccFOcCCNN)O1cc(c2OcCcO='
# [22:43:45] SMILES Parse Error: extra close parentheses while parsing: c)CCc2c)1ccc1N)cccCcOCCCc12c(c2c=S2O)c2O1)c2c=c)1(cccOcOcCCN)ccCc1COc1c)2c1=1Occ))11CcCc2=NS(c)nOc)Occc2c)cc(Nc21OC1cN1O2CON2ccONNc2)2c)c2c2cCNCcc(11c
# [22:43:45] SMILES Parse Error: check for mistakes around position 2:
# [22:43:45] c)CCc2c)1ccc1N)cccCcOCCCc12c(c2c=S2O)c2O1
# [22:43:45] ~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'c)CCc2c)1ccc1N)cccCcOCCCc12c(c2c=S2O)c2O1)c2c=c)1(cccOcOcCCN)ccCc1COc1c)2c1=1Occ))11CcCc2=NS(c)nOc)Occc2c)cc(Nc21OC1cN1O2CON2ccONNc2)2c)c2c2cCNCcc(11c' for input: 'c)CCc2c)1ccc1N)cccCcOCCCc12c(c2c=S2O)c2O1)c2c=c)1(cccOcOcCCN)ccCc1COc1c)2c1=1Occ))11CcCc2=NS(c)nOc)Occc2c)cc(Nc21OC1cN1O2CON2ccONNc2)2c)c2c2cCNCcc(11c'
# [22:43:45] SMILES Parse Error: syntax error while parsing: OCC(2cCOCCcCc)1OC=c(2CCH))Nc=C(NcC=1(1C=)Ocn2c(c2c3cc2(1CCc)cc()cO1Cc(ccO-Cc))O(ccccO==C2c1c1c12cc1CC(c)1c2cnc)NcccCOONc)cS1cCc(ccOcO2O2C)CO=O)c)OCccc
# [22:43:45] SMILES Parse Error: check for mistakes around position 5:
# [22:43:45] OCC(2cCOCCcCc)1OC=c(2CCH))Nc=C(NcC=1(1C=)
# [22:43:45] ~~~~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'OCC(2cCOCCcCc)1OC=c(2CCH))Nc=C(NcC=1(1C=)Ocn2c(c2c3cc2(1CCc)cc()cO1Cc(ccO-Cc))O(ccccO==C2c1c1c12cc1CC(c)1c2cnc)NcccCOONc)cS1cCc(ccOcO2O2C)CO=O)c)OCccc' for input: 'OCC(2cCOCCcCc)1OC=c(2CCH))Nc=C(NcC=1(1C=)Ocn2c(c2c3cc2(1CCc)cc()cO1Cc(ccO-Cc))O(ccccO==C2c1c1c12cc1CC(c)1c2cnc)NcccCOONc)cS1cCc(ccOcO2O2C)CO=O)c)OCccc'
# [22:43:45] SMILES Parse Error: extra close parentheses while parsing: Nc1cCcc2c=2O2c2c2C=C)2)(cc1c2c1C)cOcccccCON1ccc()CO(cc)Cc2=O)cONcC=(]11(c1CC)=NOO1)C2c32((CCcc((NOcc)1]NC)c2ccccCc)C=Ocn1=CO)cc-cNNcCcc(c2c2c=COc2)ONc
# [22:43:45] SMILES Parse Error: check for mistakes around position 21:
# [22:43:45] Nc1cCcc2c=2O2c2c2C=C)2)(cc1c2c1C)cOcccccC
# [22:43:45] ~~~~~~~~~~~~~~~~~~~~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'Nc1cCcc2c=2O2c2c2C=C)2)(cc1c2c1C)cOcccccCON1ccc()CO(cc)Cc2=O)cONcC=(]11(c1CC)=NOO1)C2c32((CCcc((NOcc)1]NC)c2ccccCc)C=Ocn1=CO)cc-cNNcCcc(c2c2c=COc2)ONc' for input: 'Nc1cCcc2c=2O2c2c2C=C)2)(cc1c2c1C)cOcccccCON1ccc()CO(cc)Cc2=O)cONcC=(]11(c1CC)=NOO1)C2c32((CCcc((NOcc)1]NC)c2ccccCc)C=Ocn1=CO)cc-cNNcCcc(c2c2c=COc2)ONc'
# [22:43:45] SMILES Parse Error: extra close parentheses while parsing: ccC1cONO(C)CcOC2)cC1cccc)OCc2c))Nc-cc1cCOOc(12CO((1cNnc=)cCC(C1cCOC1(cCcCCcCOcNcC2N(N(O(1(c(cc1c]Ccc(c)1CccCcCcc1CcC1cC)1(2321)(11ccOcc2ccc2c=))2cccNC
# [22:43:45] SMILES Parse Error: check for mistakes around position 17:
# [22:43:45] ccC1cONO(C)CcOC2)cC1cccc)OCc2c))Nc-cc1cCO
# [22:43:45] ~~~~~~~~~~~~~~~~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'ccC1cONO(C)CcOC2)cC1cccc)OCc2c))Nc-cc1cCOOc(12CO((1cNnc=)cCC(C1cCOC1(cCcCCcCOcNcC2N(N(O(1(c(cc1c]Ccc(c)1CccCcCcc1CcC1cC)1(2321)(11ccOcc2ccc2c=))2cccNC' for input: 'ccC1cONO(C)CcOC2)cC1cccc)OCc2c))Nc-cc1cCOOc(12CO((1cNnc=)cCC(C1cCOC1(cCcCCcCOcNcC2N(N(O(1(c(cc1c]Ccc(c)1CccCcCcc1CcC1cC)1(2321)(11ccOcc2ccc2c=))2cccNC'
# [22:43:45] SMILES Parse Error: syntax error while parsing: (NC()O1ccO)c((O)c(Ccc1c)(ccccCC(c(NONC(O21)(=CcCccOCO)CC1c(C[c)cncCc)3=cO221cc1(c)()(cN)11ONccOc2c(cc11c2c)CccCNcc13(c(22c)clCcccCNCOcCc2c)O1OccN)12cN
# [22:43:45] SMILES Parse Error: check for mistakes around position 1:
# [22:43:45] (NC()O1ccO)c((O)c(Ccc1c)(ccccCC(c(NONC(O2
# [22:43:45] ^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES '(NC()O1ccO)c((O)c(Ccc1c)(ccccCC(c(NONC(O21)(=CcCccOCO)CC1c(C[c)cncCc)3=cO221cc1(c)()(cN)11ONccOc2c(cc11c2c)CccCNcc13(c(22c)clCcccCNCOcCc2c)O1OccN)12cN' for input: '(NC()O1ccO)c((O)c(Ccc1c)(ccccCC(c(NONC(O21)(=CcCccOCO)CC1c(C[c)cncCc)3=cO221cc1(c)()(cN)11ONccOc2c(cc11c2c)CccCNcc13(c(22c)clCcccCNCOcCc2c)O1OccN)12cN'
# [22:43:45] SMILES Parse Error: extra close parentheses while parsing: O)CNCCcCCccccOcC1OcO)=CccOO)1c)CcO(CNOOCcccCc2)C)=OC)O22cOCCO111SOcC)1C2cCc=cCC1))c1CNcNc)ccS)O=CcccOCC)1CCcOccCccNN()NCO)cCccCcc=O(cCNNcccC)2CNC12=cN
# [22:43:45] SMILES Parse Error: check for mistakes around position 2:
# [22:43:45] O)CNCCcCCccccOcC1OcO)=CccOO)1c)CcO(CNOOCc
# [22:43:45] ~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'O)CNCCcCCccccOcC1OcO)=CccOO)1c)CcO(CNOOCcccCc2)C)=OC)O22cOCCO111SOcC)1C2cCc=cCC1))c1CNcNc)ccS)O=CcccOCC)1CCcOccCccNN()NCO)cCccCcc=O(cCNNcccC)2CNC12=cN' for input: 'O)CNCCcCCccccOcC1OcO)=CccOO)1c)CcO(CNOOCcccCc2)C)=OC)O22cOCCO111SOcC)1C2cCc=cCC1))c1CNcNc)ccS)O=CcccOCC)1CCcOccCccNN()NCO)cCccCcc=O(cCNNcccC)2CNC12=cN'
# [22:43:45] SMILES Parse Error: syntax error while parsing: )O1))1)cC2C1)=1(cCc2(CcccNcN(C1)2CCO1=c1)CC)2)(cHcCC2C(cCccc2NOCCcOCCc)cccC1c1cOO(C)OCNcO)=cC)ccC))Cc2ccC2)))cN31)ccc2cNOcc()Nc=1ccOc(c2c]ccOCCO1cOcOC
# [22:43:45] SMILES Parse Error: check for mistakes around position 1:
# [22:43:45] )O1))1)cC2C1)=1(cCc2(CcccNcN(C1)2CCO1=c1)
# [22:43:45] ^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES ')O1))1)cC2C1)=1(cCc2(CcccNcN(C1)2CCO1=c1)CC)2)(cHcCC2C(cCccc2NOCCcOCCc)cccC1c1cOO(C)OCNcO)=cC)ccC))Cc2ccC2)))cN31)ccc2cNOcc()Nc=1ccOc(c2c]ccOCCO1cOcOC' for input: ')O1))1)cC2C1)=1(cCc2(CcccNcN(C1)2CCO1=c1)CC)2)(cHcCC2C(cCccc2NOCCcOCCc)cccC1c1cOO(C)OCNcO)=cC)ccC))Cc2ccC2)))cN31)ccc2cNOcc()Nc=1ccOc(c2c]ccOCCO1cOcOC'
# [22:43:45] SMILES Parse Error: syntax error while parsing: cCccc2=n=CNC1ccO1OcN22cO22cO1C1cOC2C(1C=ccCOCOC)ccccc]O)1)OccOc)O)OO)cc(c)N1ONO(2)2CC)N1c1O)c(ccCNcCN2n2cNcO))c1cn)CcCnc22c1c=CHcCc2)NC)cOC)S1c2c(cC1c
# [22:43:45] SMILES Parse Error: check for mistakes around position 38:
# [22:43:45] OcN22cO22cO1C1cOC2C(1C=ccCOCOC)ccccc]O)1)
# [22:43:45] ~~~~~~~~~~~~~~~~~~~~^
# [22:43:45] SMILES Parse Error: Failed parsing SMILES 'cCccc2=n=CNC1ccO1OcN22cO22cO1C1cOC2C(1C=ccCOCOC)ccccc]O)1)OccOc)O)OO)cc(c)N1ONO(2)2CC)N1c1O)c(ccCNcCN2n2cNcO))c1cn)CcCnc22c1c=CHcCc2)NC)cOC)S1c2c(cC1c' for input: 'cCccc2=n=CNC1ccO1OcN22cO22cO1C1cOC2C(1C=ccCOCOC)ccccc]O)1)OccOc)O)OO)cc(c)N1ONO(2)2CC)N1c1O)c(ccCNcCN2n2cNcO))c1cn)CcCnc22c1c=CHcCc2)NC)cOC)S1c2c(cC1c'
# Generated samples (validity rate: 0.00%):
# 1. c)CCc2O((1cCcc((c)ccO1)cccc=O))Oc=[OCc)1c((CCcCc2ONc1)C(c)C)C(2c=cccc2OCN))NcOcc2OcC)cCcCcc2ccc=O2cc=c2CC2cCOc(2cO)1O12c)1)C)=c1))ncc1)c)O)ccCcCCcN)NN
# 2. cNOcCN1CccOc=-Cc(NccccCncCcC)ccccCOC2CccOc2OCc11cccc2)cncOc=Cc=c(CScOCOC))O))c))Cc1N(cCcOcN[cH=((cCNN)O)c=2(C)cc=c)c11cOCOc21OcccFOcCCNN)O1cc(c2OcCcO=
# 3. c)CCc2c)1ccc1N)cccCcOCCCc12c(c2c=S2O)c2O1)c2c=c)1(cccOcOcCCN)ccCc1COc1c)2c1=1Occ))11CcCc2=NS(c)nOc)Occc2c)cc(Nc21OC1cN1O2CON2ccONNc2)2c)c2c2cCNCcc(11c
# 4. OCC(2cCOCCcCc)1OC=c(2CCH))Nc=C(NcC=1(1C=)Ocn2c(c2c3cc2(1CCc)cc()cO1Cc(ccO-Cc))O(ccccO==C2c1c1c12cc1CC(c)1c2cnc)NcccCOONc)cS1cCc(ccOcO2O2C)CO=O)c)OCccc
# 5. Nc1cCcc2c=2O2c2c2C=C)2)(cc1c2c1C)cOcccccCON1ccc()CO(cc)Cc2=O)cONcC=(]11(c1CC)=NOO1)C2c32((CCcc((NOcc)1]NC)c2ccccCc)C=Ocn1=CO)cc-cNNcCcc(c2c2c=COc2)ONc
# Valid samples:
# Epoch: 31, Batch: 0, Loss: 10309518336.0000
# Epoch: 31, Batch: 10, Loss: 27131799552.0000
# Epoch: 31, Batch: 20, Loss: 8700445696.0000
# Epoch: 31, Batch: 30, Loss: 67510304768.0000
# Epoch: 31, Batch: 40, Loss: 11824068608.0000
# Epoch: 31, Batch: 50, Loss: 3385599232.0000
# Epoch: 31, Batch: 60, Loss: 2272068608.0000
# Epoch: 31, Batch: 70, Loss: 1705632256.0000
# Epoch: 31, Batch: 80, Loss: 3475378944.0000
# Epoch 31, Average loss: 8181263554.8666
# Epoch: 32, Batch: 0, Loss: 35655086080.0000
# Epoch: 32, Batch: 10, Loss: 2038359296.0000
# Epoch: 32, Batch: 20, Loss: 2822051584.0000
# Epoch: 32, Batch: 30, Loss: 1646481408.0000
# Epoch: 32, Batch: 40, Loss: 15255659520.0000
# Epoch: 32, Batch: 50, Loss: 6380491776.0000
# Epoch: 32, Batch: 60, Loss: 8658694144.0000
# Epoch: 32, Batch: 70, Loss: 6671517184.0000
# Epoch: 32, Batch: 80, Loss: 2966046720.0000
# Epoch 32, Average loss: 10292306882.5534
# Epoch: 33, Batch: 0, Loss: 2016523136.0000
# Epoch: 33, Batch: 10, Loss: -20053.2422
# Epoch: 33, Batch: 20, Loss: 4349058560.0000
# Epoch: 33, Batch: 30, Loss: 1696421376.0000
# Epoch: 33, Batch: 40, Loss: -21001.6445
# Epoch: 33, Batch: 50, Loss: 25021358080.0000
# Epoch: 33, Batch: 60, Loss: 1437506688.0000
# Epoch: 33, Batch: 70, Loss: 1987273984.0000
# Epoch: 33, Batch: 80, Loss: 7176057344.0000
# Epoch 33, Average loss: 4500285546.5188
# Epoch: 34, Batch: 0, Loss: -18702.0898
# Epoch: 34, Batch: 10, Loss: 6757585408.0000
# Epoch: 34, Batch: 20, Loss: 13887582208.0000
# Epoch: 34, Batch: 30, Loss: 14692945920.0000
# Epoch: 34, Batch: 40, Loss: 9394246656.0000
# Epoch: 34, Batch: 50, Loss: 10336560128.0000
# Epoch: 34, Batch: 60, Loss: 6655985152.0000
# Epoch: 34, Batch: 70, Loss: -21270.0312
# Epoch: 34, Batch: 80, Loss: 2263664128.0000
# Epoch 34, Average loss: 7907820517.8288
# Epoch: 35, Batch: 0, Loss: 6536586240.0000
# Epoch: 35, Batch: 10, Loss: 8044435968.0000
# Epoch: 35, Batch: 20, Loss: 2954538752.0000
# Epoch: 35, Batch: 30, Loss: -20171.9609
# Epoch: 35, Batch: 40, Loss: 7969903616.0000
# Epoch: 35, Batch: 50, Loss: 5992368640.0000
# Epoch: 35, Batch: 60, Loss: 3071780352.0000
# Epoch: 35, Batch: 70, Loss: -19545.3613
# Epoch: 35, Batch: 80, Loss: 1986429056.0000
# Epoch 35, Average loss: 11795749068.9866
# Epoch: 36, Batch: 0, Loss: -18713.8438
# Epoch: 36, Batch: 10, Loss: 3872863232.0000
# Epoch: 36, Batch: 20, Loss: 938362688.0000
# Epoch: 36, Batch: 30, Loss: -20822.7422
# Epoch: 36, Batch: 40, Loss: 25295097856.0000
# Epoch: 36, Batch: 50, Loss: 1286946944.0000
# Epoch: 36, Batch: 60, Loss: 3997622784.0000
# Epoch: 36, Batch: 70, Loss: 4899785216.0000
# Epoch: 36, Batch: 80, Loss: 1342708608.0000
# Epoch 36, Average loss: 5343272870.0447
# Epoch: 37, Batch: 0, Loss: 20286801920.0000
# Epoch: 37, Batch: 10, Loss: 17036795904.0000
# Epoch: 37, Batch: 20, Loss: -18444.3066
# Epoch: 37, Batch: 30, Loss: 1563133952.0000
# Epoch: 37, Batch: 40, Loss: 1951160064.0000
# Epoch: 37, Batch: 50, Loss: 533394144.0000
# Epoch: 37, Batch: 60, Loss: 1427024512.0000
# Epoch: 37, Batch: 70, Loss: 541772352.0000
# Epoch: 37, Batch: 80, Loss: 577841280.0000
# Epoch 37, Average loss: 3791308656.1725
# Epoch: 38, Batch: 0, Loss: 2321846784.0000
# Epoch: 38, Batch: 10, Loss: 7009839104.0000
# Epoch: 38, Batch: 20, Loss: 16602240000.0000
# Epoch: 38, Batch: 30, Loss: -18179.3535
# Epoch: 38, Batch: 40, Loss: 1489409408.0000
# Epoch: 38, Batch: 50, Loss: 12563303424.0000
# Epoch: 38, Batch: 60, Loss: 12645673984.0000
# Epoch: 38, Batch: 70, Loss: 2012862720.0000
# Epoch: 38, Batch: 80, Loss: 8419811840.0000
# Epoch 38, Average loss: 6066555348.7593
# Epoch: 39, Batch: 0, Loss: 5820556288.0000
# Epoch: 39, Batch: 10, Loss: 1151673472.0000
# Epoch: 39, Batch: 20, Loss: 6021503488.0000
# Epoch: 39, Batch: 30, Loss: 34561011712.0000
# Epoch: 39, Batch: 40, Loss: 12897167360.0000
# Epoch: 39, Batch: 50, Loss: 6652127744.0000
# Epoch: 39, Batch: 60, Loss: -21285.7656
# Epoch: 39, Batch: 70, Loss: 26167912448.0000
# Epoch: 39, Batch: 80, Loss: 3154193152.0000
# Epoch 39, Average loss: 6911923355.3229
# Epoch: 40, Batch: 0, Loss: -22491.1387
# Epoch: 40, Batch: 10, Loss: 1440411136.0000
# Epoch: 40, Batch: 20, Loss: 978390272.0000
# Epoch: 40, Batch: 30, Loss: 11115559936.0000
# Epoch: 40, Batch: 40, Loss: 4041495552.0000
# Epoch: 40, Batch: 50, Loss: 1448900096.0000
# Epoch: 40, Batch: 60, Loss: 723867968.0000
# Epoch: 40, Batch: 70, Loss: -22485.0000
# Epoch: 40, Batch: 80, Loss: 1502235264.0000
# Epoch 40, Average loss: 3475952175.0344
# [22:44:03] SMILES Parse Error: syntax error while parsing: =cO2)2cc2OccN)cO2ccc(CccOcccCNc1ccc)2N)2cc(c(cC1NnccccCcNccO=C1CcCcCcc(c2cCNc2cc))cnCccccOO)1O)(2c1cCOcCcccccccC2)2Cc(c(cccc2cc(CccCc)ccCccCc)cc2cCCcC
# [22:44:03] SMILES Parse Error: check for mistakes around position 1:
# [22:44:03] =cO2)2cc2OccN)cO2ccc(CccOcccCNc1ccc)2N)2c
# [22:44:03] ^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES '=cO2)2cc2OccN)cO2ccc(CccOcccCNc1ccc)2N)2cc(c(cC1NnccccCcNccO=C1CcCcCcc(c2cCNc2cc))cnCccccOO)1O)(2c1cCOcCcccccccC2)2Cc(c(cccc2cc(CccCc)ccCccCc)cc2cCCcC' for input: '=cO2)2cc2OccN)cO2ccc(CccOcccCNc1ccc)2N)2cc(c(cC1NnccccCcNccO=C1CcCcCcc(c2cCNc2cc))cnCccccOO)1O)(2c1cCOcCcccccccC2)2Cc(c(cccc2cc(CccCc)ccCccCc)cc2cCCcC'
# [22:44:03] SMILES Parse Error: syntax error while parsing: 12cc(c2cc))ccc)cC)ccCCc=CcOO2(cCc=2Cc22c11cc1NN2NCCCcC2C2ccccCc(ccCc2O2N=2))2cCONccN)ccCCcC1C2ccc(c2c12cc)cC2C2Nc)112cNcccccc)2=cC2cCcCc2(OOcOc)cCccCc
# [22:44:03] SMILES Parse Error: check for mistakes around position 1:
# [22:44:03] 12cc(c2cc))ccc)cC)ccCCc=CcOO2(cCc=2Cc22c1
# [22:44:03] ^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES '12cc(c2cc))ccc)cC)ccCCc=CcOO2(cCc=2Cc22c11cc1NN2NCCCcC2C2ccccCc(ccCc2O2N=2))2cCONccN)ccCCcC1C2ccc(c2c12cc)cC2C2Nc)112cNcccccc)2=cC2cCcCc2(OOcOc)cCccCc' for input: '12cc(c2cc))ccc)cC)ccCCc=CcOO2(cCc=2Cc22c11cc1NN2NCCCcC2C2ccccCc(ccCc2O2N=2))2cCONccN)ccCCcC1C2ccc(c2c12cc)cC2C2Nc)112cNcccccc)2=cC2cCcCc2(OOcOc)cCccCc'
# [22:44:03] SMILES Parse Error: syntax error while parsing: )2cC(c)12ccc2cCCOccOcCc)NcO1(c(cccc1(2)cc1ccOONccc2cCONcc(cccONcCcccccCC()(=c2CcOC(ccCcccCC2c2=ccCccCcccC2C=c2cc2cCcccccN)N)1)(ccccNccccNO)Ccc(c(2cccO
# [22:44:03] SMILES Parse Error: check for mistakes around position 1:
# [22:44:03] )2cC(c)12ccc2cCCOccOcCc)NcO1(c(cccc1(2)cc
# [22:44:03] ^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES ')2cC(c)12ccc2cCCOccOcCc)NcO1(c(cccc1(2)cc1ccOONccc2cCONcc(cccONcCcccccCC()(=c2CcOC(ccCcccCC2c2=ccCccCcccC2C=c2cc2cCcccccN)N)1)(ccccNccccNO)Ccc(c(2cccO' for input: ')2cC(c)12ccc2cCCOccOcCc)NcO1(c(cccc1(2)cc1ccOONccc2cCONcc(cccONcCcccccCC()(=c2CcOC(ccCcccCC2c2=ccCccCcccC2C=c2cc2cCcccccN)N)1)(ccccNccccNO)Ccc(c(2cccO'
# [22:44:03] SMILES Parse Error: extra close parentheses while parsing: c2ccCc=Cc2)1N2)1ccC=2NccC2cC)cO12Nc1(NcN2c2CCncCcSCC)Ccc(1)OcC(CCcCC))OC2(ccc2c1cccc2Occcc2cc(c1ccCcCcccc12c2Cc21CO)2cNccCcC1cCOOO2c((ccccC2c2c22O1N(=
# [22:44:03] SMILES Parse Error: check for mistakes around position 11:
# [22:44:03] c2ccCc=Cc2)1N2)1ccC=2NccC2cC)cO12Nc1(NcN2
# [22:44:03] ~~~~~~~~~~^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES 'c2ccCc=Cc2)1N2)1ccC=2NccC2cC)cO12Nc1(NcN2c2CCncCcSCC)Ccc(1)OcC(CCcCC))OC2(ccc2c1cccc2Occcc2cc(c1ccCcCcccc12c2Cc21CO)2cNccCcC1cCOOO2c((ccccC2c2c22O1N(=' for input: 'c2ccCc=Cc2)1N2)1ccC=2NccC2cC)cO12Nc1(NcN2c2CCncCcSCC)Ccc(1)OcC(CCcCC))OC2(ccc2c1cccc2Occcc2cc(c1ccCcCcccc12c2Cc21CO)2cNccCcC1cCOOO2c((ccccC2c2c22O1N(='
# [22:44:03] SMILES Parse Error: syntax error while parsing: (1c(C1ccc3c)(ccc)c(cC)12(1(cCcccC2CcN2))(cc1N(CCcc(cCCcCcCClNC2O2=(=CCCccccC1c=2cccC)c22c2C2cCcCccccCcCOC2NCcCcCC=cc2c)CCCcccCCC2Cccc2(CcCNC111Cc(cccc
# [22:44:03] SMILES Parse Error: check for mistakes around position 1:
# [22:44:03] (1c(C1ccc3c)(ccc)c(cC)12(1(cCcccC2CcN2))(
# [22:44:03] ^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES '(1c(C1ccc3c)(ccc)c(cC)12(1(cCcccC2CcN2))(cc1N(CCcc(cCCcCcCClNC2O2=(=CCCccccC1c=2cccC)c22c2C2cCcCccccCcCOC2NCcCcCC=cc2c)CCCcccCCC2Cccc2(CcCNC111Cc(cccc' for input: '(1c(C1ccc3c)(ccc)c(cC)12(1(cCcccC2CcN2))(cc1N(CCcc(cCCcCcCClNC2O2=(=CCCccccC1c=2cccC)c22c2C2cCcCccccCcCOC2NCcCcCC=cc2c)CCCcccCCC2Cccc2(CcCNC111Cc(cccc'
# [22:44:03] SMILES Parse Error: extra close parentheses while parsing: Ncc)cccC1Nc(Ncc(=N)OcccC2cc(cNOC(OcccccC2c)))ccccc))cc)c2))Oc1cNCccc2ccCCN)c(Occcc2cC2cc1ccCcccccccOC2=2CcccCCC=c2N)Nc=2CcccNcOC))cCccC2ONCcccccCCO(cO
# [22:44:03] SMILES Parse Error: check for mistakes around position 4:
# [22:44:03] Ncc)cccC1Nc(Ncc(=N)OcccC2cc(cNOC(OcccccC2
# [22:44:03] ~~~^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES 'Ncc)cccC1Nc(Ncc(=N)OcccC2cc(cNOC(OcccccC2c)))ccccc))cc)c2))Oc1cNCccc2ccCCN)c(Occcc2cC2cc1ccCcccccccOC2=2CcccCCC=c2N)Nc=2CcccNcOC))cCccC2ONCcccccCCO(cO' for input: 'Ncc)cccC1Nc(Ncc(=N)OcccC2cc(cNOC(OcccccC2c)))ccccc))cc)c2))Oc1cNCccc2ccCCN)c(Occcc2cC2cc1ccCcccccccOC2=2CcccCCC=c2N)Nc=2CcccNcOC))cCccC2ONCcccccCCO(cO'
# [22:44:03] SMILES Parse Error: extra close parentheses while parsing: c)NN2CcNNc2ccO2ccccccc()2c1c2(2cOcC)CCO1NNcC)c1cOCCcC2)cc)2))c(N=cc)OCCccc22cc2(c2c)O1C)2cccccC(=2c1)nccNcCCCOCc2NOCC)2c2cccNcc2ON()ccC))cc=cC)c2ccCCc
# [22:44:03] SMILES Parse Error: check for mistakes around position 2:
# [22:44:03] c)NN2CcNNc2ccO2ccccccc()2c1c2(2cOcC)CCO1N
# [22:44:03] ~^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES 'c)NN2CcNNc2ccO2ccccccc()2c1c2(2cOcC)CCO1NNcC)c1cOCCcC2)cc)2))c(N=cc)OCCccc22cc2(c2c)O1C)2cccccC(=2c1)nccNcCCCOCc2NOCC)2c2cccNcc2ON()ccC))cc=cC)c2ccCCc' for input: 'c)NN2CcNNc2ccO2ccccccc()2c1c2(2cOcC)CCO1NNcC)c1cOCCcC2)cc)2))c(N=cc)OCCccc22cc2(c2c)O1C)2cccccC(=2c1)nccNcCCCOCc2NOCC)2c2cccNcc2ON()ccC))cc=cC)c2ccCCc'
# [22:44:03] SMILES Parse Error: extra close parentheses while parsing: OO2)cc22C)nccC)cOc)(ccCcCCCScC2ccCc2c2C2)cC(c)C)Ncc(2cCCCc2=cCC)CcOcc2ccN21(cCCCOC2c2ccNCcc()=cc(C2cc2l2C2)CcN(22CcCC21COccccc2cc)cccCCc1CSc(22O)ccc=2
# [22:44:03] SMILES Parse Error: check for mistakes around position 4:
# [22:44:03] OO2)cc22C)nccC)cOc)(ccCcCCCScC2ccCc2c2C2)
# [22:44:03] ~~~^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES 'OO2)cc22C)nccC)cOc)(ccCcCCCScC2ccCc2c2C2)cC(c)C)Ncc(2cCCCc2=cCC)CcOcc2ccN21(cCCCOC2c2ccNCcc()=cc(C2cc2l2C2)CcN(22CcCC21COccccc2cc)cccCCc1CSc(22O)ccc=2' for input: 'OO2)cc22C)nccC)cOc)(ccCcCCCScC2ccCc2c2C2)cC(c)C)Ncc(2cCCCc2=cCC)CcOcc2ccN21(cCCCOC2c2ccNCcc()=cc(C2cc2l2C2)CcN(22CcCC21COccccc2cc)cccCCc1CSc(22O)ccc=2'
# [22:44:03] SMILES Parse Error: extra close parentheses while parsing: SN)((cC)C)2ccCcOccOCcccccc)cCCccCCO1c1n(c)CccOccCccO2C2CC2c1Cc1Cc)2c2)2)ccnccc2cN2c2cnC2)c)1cNN(NccCccC=cCNCcC)c=cCcNc2c)CNC2cccCC)cOc2ccnccCccc))ccNc
# [22:44:03] SMILES Parse Error: check for mistakes around position 3:
# [22:44:03] SN)((cC)C)2ccCcOccOCcccccc)cCCccCCO1c1n(c
# [22:44:03] ~~^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES 'SN)((cC)C)2ccCcOccOCcccccc)cCCccCCO1c1n(c)CccOccCccO2C2CC2c1Cc1Cc)2c2)2)ccnccc2cN2c2cnC2)c)1cNN(NccCccC=cCNCcC)c=cCcNc2c)CNC2cccCC)cOc2ccnccCccc))ccNc' for input: 'SN)((cC)C)2ccCcOccOCcccccc)cCCccCCO1c1n(c)CccOccCccO2C2CC2c1Cc1Cc)2c2)2)ccnccc2cN2c2cnC2)c)1cNN(NccCccC=cCNCcC)c=cCcNc2c)CNC2cccCC)cOc2ccnccCccc))ccNc'
# [22:44:03] SMILES Parse Error: extra close parentheses while parsing: cCc2ncC=cccCccccc)2()CC)cccCccccccccCNNcc(c2cNc)c(cc2c2)cCCOCCCccnC2ccCCO2cS=3222cccCCC=2NN)1NcCc12c2ccccc2ccC1O2NcC)CccN)N)(cCC(2c(ccCCc(c2c(2ccCCcN1
# [22:44:03] SMILES Parse Error: check for mistakes around position 18:
# [22:44:03] cCc2ncC=cccCccccc)2()CC)cccCccccccccCNNcc
# [22:44:03] ~~~~~~~~~~~~~~~~~^
# [22:44:03] SMILES Parse Error: Failed parsing SMILES 'cCc2ncC=cccCccccc)2()CC)cccCccccccccCNNcc(c2cNc)c(cc2c2)cCCOCCCccnC2ccCCO2cS=3222cccCCC=2NN)1NcCc12c2ccccc2ccC1O2NcC)CccN)N)(cCC(2c(ccCCc(c2c(2ccCCcN1' for input: 'cCc2ncC=cccCccccc)2()CC)cccCccccccccCNNcc(c2cNc)c(cc2c2)cCCOCCCccnC2ccCCO2cS=3222cccCCC=2NN)1NcCc12c2ccccc2ccC1O2NcC)CccN)N)(cCC(2c(ccCCc(c2c(2ccCCcN1'
# Generated samples (validity rate: 0.00%):
# 1. =cO2)2cc2OccN)cO2ccc(CccOcccCNc1ccc)2N)2cc(c(cC1NnccccCcNccO=C1CcCcCcc(c2cCNc2cc))cnCccccOO)1O)(2c1cCOcCcccccccC2)2Cc(c(cccc2cc(CccCc)ccCccCc)cc2cCCcC
# 2. 12cc(c2cc))ccc)cC)ccCCc=CcOO2(cCc=2Cc22c11cc1NN2NCCCcC2C2ccccCc(ccCc2O2N=2))2cCONccN)ccCCcC1C2ccc(c2c12cc)cC2C2Nc)112cNcccccc)2=cC2cCcCc2(OOcOc)cCccCc
# 3. )2cC(c)12ccc2cCCOccOcCc)NcO1(c(cccc1(2)cc1ccOONccc2cCONcc(cccONcCcccccCC()(=c2CcOC(ccCcccCC2c2=ccCccCcccC2C=c2cc2cCcccccN)N)1)(ccccNccccNO)Ccc(c(2cccO
# 4. c2ccCc=Cc2)1N2)1ccC=2NccC2cC)cO12Nc1(NcN2c2CCncCcSCC)Ccc(1)OcC(CCcCC))OC2(ccc2c1cccc2Occcc2cc(c1ccCcCcccc12c2Cc21CO)2cNccCcC1cCOOO2c((ccccC2c2c22O1N(=
# 5. (1c(C1ccc3c)(ccc)c(cC)12(1(cCcccC2CcN2))(cc1N(CCcc(cCCcCcCClNC2O2=(=CCCccccC1c=2cccC)c22c2C2cCcCccccCcCOC2NCcCcCC=cc2c)CCCcccCCC2Cccc2(CcCNC111Cc(cccc
# Valid samples:
# Epoch: 41, Batch: 0, Loss: 2592327680.0000
# Epoch: 41, Batch: 10, Loss: 2252408320.0000
# Epoch: 41, Batch: 20, Loss: 1924909952.0000
# Epoch: 41, Batch: 30, Loss: 1241822080.0000
# Epoch: 41, Batch: 40, Loss: 1078174976.0000
# Epoch: 41, Batch: 50, Loss: 453223104.0000
# Epoch: 41, Batch: 60, Loss: 419260032.0000
# Epoch: 41, Batch: 70, Loss: 394953024.0000
# Epoch: 41, Batch: 80, Loss: 1517437184.0000
# Epoch 41, Average loss: 2340929800.3547
# Epoch: 42, Batch: 0, Loss: -20701.4062
# Epoch: 42, Batch: 10, Loss: 910673792.0000
# Epoch: 42, Batch: 20, Loss: 2641336832.0000
# Epoch: 42, Batch: 30, Loss: -22376.5742
# Epoch: 42, Batch: 40, Loss: -22085.4766
# Epoch: 42, Batch: 50, Loss: 2364447488.0000
# Epoch: 42, Batch: 60, Loss: 1408336896.0000
# Epoch: 42, Batch: 70, Loss: 6125919744.0000
# Epoch: 42, Batch: 80, Loss: 6325774848.0000
# Epoch 42, Average loss: 7060997826.5000
# Epoch: 43, Batch: 0, Loss: 5557671424.0000
# Epoch: 43, Batch: 10, Loss: 4793288192.0000
# Epoch: 43, Batch: 20, Loss: 669929536.0000
# Epoch: 43, Batch: 30, Loss: 1690563584.0000
# Epoch: 43, Batch: 40, Loss: -18032.8320
# Epoch: 43, Batch: 50, Loss: 4092452096.0000
# Epoch: 43, Batch: 60, Loss: 1137010944.0000
# Epoch: 43, Batch: 70, Loss: 1197720704.0000
# Epoch: 43, Batch: 80, Loss: 401566176.0000
# Epoch 43, Average loss: 3047068554.9584
# Epoch: 44, Batch: 0, Loss: 6130193408.0000
# Epoch: 44, Batch: 10, Loss: 356106816.0000
# Epoch: 44, Batch: 20, Loss: 336961120.0000
# Epoch: 44, Batch: 30, Loss: -16085.9434
# Epoch: 44, Batch: 40, Loss: -19566.4688
# Epoch: 44, Batch: 50, Loss: -21741.9688
# Epoch: 44, Batch: 60, Loss: 1236324224.0000
# Epoch: 44, Batch: 70, Loss: 26051950592.0000
# Epoch: 44, Batch: 80, Loss: 2110719104.0000
# Epoch 44, Average loss: 6225317468.9393
# Epoch: 45, Batch: 0, Loss: 1651579392.0000
# Epoch: 45, Batch: 10, Loss: 2760916480.0000
# Epoch: 45, Batch: 20, Loss: 1511632000.0000
# Epoch: 45, Batch: 30, Loss: -21925.8555
# Epoch: 45, Batch: 40, Loss: 17293277184.0000
# Epoch: 45, Batch: 50, Loss: 646419456.0000
# Epoch: 45, Batch: 60, Loss: 1428797184.0000
# Epoch: 45, Batch: 70, Loss: 7524899840.0000
# Epoch: 45, Batch: 80, Loss: -21053.2344
# Epoch 45, Average loss: 6610343544.2429
# Epoch: 46, Batch: 0, Loss: 27958788096.0000
# Epoch: 46, Batch: 10, Loss: 1143510144.0000
# Epoch: 46, Batch: 20, Loss: 2305324544.0000
# Epoch: 46, Batch: 30, Loss: 4347522048.0000
# Epoch: 46, Batch: 40, Loss: 2425541376.0000
# Epoch: 46, Batch: 50, Loss: 1527739776.0000
# Epoch: 46, Batch: 60, Loss: 6427699200.0000
# Epoch: 46, Batch: 70, Loss: 2830866688.0000
# Epoch: 46, Batch: 80, Loss: 1829511552.0000
# Epoch 46, Average loss: 3916551048.5159
# Epoch: 47, Batch: 0, Loss: 350825952.0000
# Epoch: 47, Batch: 10, Loss: 2050408832.0000
# Epoch: 47, Batch: 20, Loss: 3398235392.0000
# Epoch: 47, Batch: 30, Loss: 310204512.0000
# Epoch: 47, Batch: 40, Loss: 1225952384.0000
# Epoch: 47, Batch: 50, Loss: 1041088896.0000
# Epoch: 47, Batch: 60, Loss: 625357056.0000
# Epoch: 47, Batch: 70, Loss: 2148195072.0000
# Epoch: 47, Batch: 80, Loss: 2390882304.0000
# Epoch 47, Average loss: 1752345937.7310
# Epoch: 48, Batch: 0, Loss: 351255552.0000
# Epoch: 48, Batch: 10, Loss: 2475458816.0000
# Epoch: 48, Batch: 20, Loss: 660879232.0000
# Epoch: 48, Batch: 30, Loss: 320470496.0000
# Epoch: 48, Batch: 40, Loss: 701811712.0000
# Epoch: 48, Batch: 50, Loss: 1904957568.0000
# Epoch: 48, Batch: 60, Loss: 585744256.0000
# Epoch: 48, Batch: 70, Loss: -22240.5742
# Epoch: 48, Batch: 80, Loss: 604329792.0000
# Epoch 48, Average loss: 1328014901.5720
# Epoch: 49, Batch: 0, Loss: 2458219776.0000
# Epoch: 49, Batch: 10, Loss: 2221092608.0000
# Epoch: 49, Batch: 20, Loss: 892975040.0000
# Epoch: 49, Batch: 30, Loss: 3430919680.0000
# Epoch: 49, Batch: 40, Loss: 1942923904.0000
# Epoch: 49, Batch: 50, Loss: 3095817984.0000
# Epoch: 49, Batch: 60, Loss: -25660.1953
# Epoch: 49, Batch: 70, Loss: -23879.1621
# Epoch: 49, Batch: 80, Loss: 9550899200.0000
# Epoch 49, Average loss: 3148314848.2414
# Epoch: 50, Batch: 0, Loss: 3157662208.0000
# Epoch: 50, Batch: 10, Loss: 403808096.0000
# Epoch: 50, Batch: 20, Loss: 302027616.0000
# Epoch: 50, Batch: 30, Loss: -21409.0273
# Epoch: 50, Batch: 40, Loss: 1025076672.0000
# Epoch: 50, Batch: 50, Loss: 574389696.0000
# Epoch: 50, Batch: 60, Loss: 3950247680.0000
# Epoch: 50, Batch: 70, Loss: -24883.6445
# Epoch: 50, Batch: 80, Loss: 529723104.0000
# Epoch 50, Average loss: 1944787409.0565
# Generated samples (validity rate: 0.00%):
# 1. =1)=)CNc22C)cC(cccN2(1)OCcC(cO)Occ)c()N)(cNO=)c(cncc2C1(cc(cCccNONCcc=2)Ccnc)cccOc)==Ccc(ccCOcc)Cc1CcCOCCNcCc1cc(cO=Cccccc=cc=)cCccc)cnccScc(c2OCccC)1
# 2. OcOcCc=()cCc)NccCOCccc)cC2ccc(CcccccNcCc(C)C)c)O)((C)c)C()=c2O1NO=cC=Ccc2cCCc2(cCOc)C)==c)c=((cC)N)ccccC)OcOcc())NCccc(cn)cccCc(nc(2ccc)Cc2C=O)n)OcC)O
# 3. cccS))cNN)cOcc(cccOCO)OcccccCnccc)cccOcOc(N=Occcc)=N=nCccnC)c(Oc2cCc)cc2cCc1(c2ccc1c1ccc)Cccc(COO)1)cc)ccc)2(ccNcccccO=c())ccc(cN2ccC=()Cc=ccOc22c(Occ
# 4. c)2cCcOC(ccOcnccNcc(=CN(Nc)cOC1c(=c1cc)CCCOn)Cc)2CcCOCCcccOc1ccC1cO=cCcOcC))c)cOcc)CccCccCN)C)c)(cC))cCcNcCcOcCC(C(NCccccCcSOcCOc=C)c)ccccOC2c(Nc(C)Cc
# 5. ==2c2c(c(cOc)O1()cCCCcO)NN)2OO1NO=CcOc=c)C)(2ccSCcc)2)N)(2)2Ccc(2cccNc()(c)cnc2Cc)N)c(cc=)n1Nc2NcO)C=c)N=NCc=(=ccOc2C1COc=22c(cccCcCCNcO)Oc=)ccc2)cNcc
# Valid samples:
# [22:44:22] SMILES Parse Error: syntax error while parsing: =1)=)CNc22C)cC(cccN2(1)OCcC(cO)Occ)c()N)(cNO=)c(cncc2C1(cc(cCccNONCcc=2)Ccnc)cccOc)==Ccc(ccCOcc)Cc1CcCOCCNcCc1cc(cO=Cccccc=cc=)cCccc)cnccScc(c2OCccC)1
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] =1)=)CNc22C)cC(cccN2(1)OCcC(cO)Occ)c()N)(
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '=1)=)CNc22C)cC(cccN2(1)OCcC(cO)Occ)c()N)(cNO=)c(cncc2C1(cc(cCccNONCcc=2)Ccnc)cccOc)==Ccc(ccCOcc)Cc1CcCOCCNcCc1cc(cO=Cccccc=cc=)cCccc)cnccScc(c2OCccC)1' for input: '=1)=)CNc22C)cC(cccN2(1)OCcC(cO)Occ)c()N)(cNO=)c(cncc2C1(cc(cCccNONCcc=2)Ccnc)cccOc)==Ccc(ccCOcc)Cc1CcCOCCNcCc1cc(cO=Cccccc=cc=)cCccc)cnccScc(c2OCccC)1'
# [22:44:22] SMILES Parse Error: syntax error while parsing: OcOcCc=()cCc)NccCOCccc)cC2ccc(CcccccNcCc(C)C)c)O)((C)c)C()=c2O1NO=cC=Ccc2cCCc2(cCOc)C)==c)c=((cC)N)ccccC)OcOcc())NCccc(cn)cccCc(nc(2ccc)Cc2C=O)n)OcC)O
# [22:44:22] SMILES Parse Error: check for mistakes around position 8:
# [22:44:22] OcOcCc=()cCc)NccCOCccc)cC2ccc(CcccccNcCc(
# [22:44:22] ~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'OcOcCc=()cCc)NccCOCccc)cC2ccc(CcccccNcCc(C)C)c)O)((C)c)C()=c2O1NO=cC=Ccc2cCCc2(cCOc)C)==c)c=((cC)N)ccccC)OcOcc())NCccc(cn)cccCc(nc(2ccc)Cc2C=O)n)OcC)O' for input: 'OcOcCc=()cCc)NccCOCccc)cC2ccc(CcccccNcCc(C)C)c)O)((C)c)C()=c2O1NO=cC=Ccc2cCCc2(cCOc)C)==c)c=((cC)N)ccccC)OcOcc())NCccc(cn)cccCc(nc(2ccc)Cc2C=O)n)OcC)O'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: cccS))cNN)cOcc(cccOCO)OcccccCnccc)cccOcOc(N=Occcc)=N=nCccnC)c(Oc2cCc)cc2cCc1(c2ccc1c1ccc)Cccc(COO)1)cc)ccc)2(ccNcccccO=c())ccc(cN2ccC=()Cc=ccOc22c(Occ
# [22:44:22] SMILES Parse Error: check for mistakes around position 5:
# [22:44:22] cccS))cNN)cOcc(cccOCO)OcccccCnccc)cccOcOc
# [22:44:22] ~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'cccS))cNN)cOcc(cccOCO)OcccccCnccc)cccOcOc(N=Occcc)=N=nCccnC)c(Oc2cCc)cc2cCc1(c2ccc1c1ccc)Cccc(COO)1)cc)ccc)2(ccNcccccO=c())ccc(cN2ccC=()Cc=ccOc22c(Occ' for input: 'cccS))cNN)cOcc(cccOCO)OcccccCnccc)cccOcOc(N=Occcc)=N=nCccnC)c(Oc2cCc)cc2cCc1(c2ccc1c1ccc)Cccc(COO)1)cc)ccc)2(ccNcccccO=c())ccc(cN2ccC=()Cc=ccOc22c(Occ'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: c)2cCcOC(ccOcnccNcc(=CN(Nc)cOC1c(=c1cc)CCCOn)Cc)2CcCOCCcccOc1ccC1cO=cCcOcC))c)cOcc)CccCccCN)C)c)(cC))cCcNcCcOcCC(C(NCccccCcSOcCOc=C)c)ccccOC2c(Nc(C)Cc
# [22:44:22] SMILES Parse Error: check for mistakes around position 2:
# [22:44:22] c)2cCcOC(ccOcnccNcc(=CN(Nc)cOC1c(=c1cc)CC
# [22:44:22] ~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'c)2cCcOC(ccOcnccNcc(=CN(Nc)cOC1c(=c1cc)CCCOn)Cc)2CcCOCCcccOc1ccC1cO=cCcOcC))c)cOcc)CccCccCN)C)c)(cC))cCcNcCcOcCC(C(NCccccCcSOcCOc=C)c)ccccOC2c(Nc(C)Cc' for input: 'c)2cCcOC(ccOcnccNcc(=CN(Nc)cOC1c(=c1cc)CCCOn)Cc)2CcCOCCcccOc1ccC1cO=cCcOcC))c)cOcc)CccCccCN)C)c)(cC))cCcNcCcOcCC(C(NCccccCcSOcCOc=C)c)ccccOC2c(Nc(C)Cc'
# [22:44:22] SMILES Parse Error: syntax error while parsing: ==2c2c(c(cOc)O1()cCCCcO)NN)2OO1NO=CcOc=c)C)(2ccSCcc)2)N)(2)2Ccc(2cccNc()(c)cnc2Cc)N)c(cc=)n1Nc2NcO)C=c)N=NCc=(=ccOc2C1COc=22c(cccCcCCNcO)Oc=)ccc2)cNcc
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] ==2c2c(c(cOc)O1()cCCCcO)NN)2OO1NO=CcOc=c)
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '==2c2c(c(cOc)O1()cCCCcO)NN)2OO1NO=CcOc=c)C)(2ccSCcc)2)N)(2)2Ccc(2cccNc()(c)cnc2Cc)N)c(cc=)n1Nc2NcO)C=c)N=NCc=(=ccOc2C1COc=22c(cccCcCCNcO)Oc=)ccc2)cNcc' for input: '==2c2c(c(cOc)O1()cCCCcO)NN)2OO1NO=CcOc=c)C)(2ccSCcc)2)N)(2)2Ccc(2cccNc()(c)cnc2Cc)N)c(cc=)n1Nc2NcO)C=c)N=NCc=(=ccOc2C1COc=22c(cccCcCCNcO)Oc=)ccc2)cNcc'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: cc)cNSO2C)=)((c)(cc1cccOC2c)nc(ccccccBccCcOc)O1Occ)Nccc1c(Cccc)Oc(OcNNSCcc2)))(cCcccO)=NC)c1=n2c1Cccc)c)cc(2)ccc))cc()cC)2C=cOccCNcc(2ccN(c)ccOcnCc)C=
# [22:44:22] SMILES Parse Error: check for mistakes around position 3:
# [22:44:22] cc)cNSO2C)=)((c)(cc1cccOC2c)nc(ccccccBccC
# [22:44:22] ~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'cc)cNSO2C)=)((c)(cc1cccOC2c)nc(ccccccBccCcOc)O1Occ)Nccc1c(Cccc)Oc(OcNNSCcc2)))(cCcccO)=NC)c1=n2c1Cccc)c)cc(2)ccc))cc()cC)2C=cOccCNcc(2ccN(c)ccOcnCc)C=' for input: 'cc)cNSO2C)=)((c)(cc1cccOC2c)nc(ccccccBccCcOc)O1Occ)Nccc1c(Cccc)Oc(OcNNSCcc2)))(cCcccO)=NC)c1=n2c1Cccc)c)cc(2)ccc))cc()cC)2C=cOccCNcc(2ccN(c)ccOcnCc)C='
# [22:44:22] SMILES Parse Error: syntax error while parsing: =cCccN(2FCCOc2ccCCCc)cC(N(2O)cccON=Ncc)n1c1c)CN2cccO)(cc)Oc(C)cccccc2c2cNcOC22C2(cC(cN2OScc)c(c)Cc(cOOc)ccOcCNccc2Ccn)(c2)cNNcO2c)ccO=O=c((COcc(N=Cccc
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] =cCccN(2FCCOc2ccCCCc)cC(N(2O)cccON=Ncc)n1
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '=cCccN(2FCCOc2ccCCCc)cC(N(2O)cccON=Ncc)n1c1c)CN2cccO)(cc)Oc(C)cccccc2c2cNcOC22C2(cC(cN2OScc)c(c)Cc(cOOc)ccOcCNccc2Ccn)(c2)cNNcO2c)ccO=O=c((COcc(N=Cccc' for input: '=cCccN(2FCCOc2ccCCCc)cC(N(2O)cccON=Ncc)n1c1c)CN2cccO)(cc)Oc(C)cccccc2c2cNcOC22C2(cC(cN2OScc)c(c)Cc(cOOc)ccOcCNccc2Ccn)(c2)cNNcO2c)ccO=O=c((COcc(N=Cccc'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: CCcCccc(SNc)C=C)NCCc2cNNcc(CcC2c2(CC)=c1C=ccNcc((cCC)C)C)1CcOSCNcnc)CcC((1c(cccccOO(CCc)(c(2C)CCNcc2ccNcOcccc)=OcCc(NcC=1Cncc(O1CCOc)c2C(c(Cccc)CCcccC
# [22:44:22] SMILES Parse Error: check for mistakes around position 16:
# [22:44:22] CCcCccc(SNc)C=C)NCCc2cNNcc(CcC2c2(CC)=c1C
# [22:44:22] ~~~~~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'CCcCccc(SNc)C=C)NCCc2cNNcc(CcC2c2(CC)=c1C=ccNcc((cCC)C)C)1CcOSCNcnc)CcC((1c(cccccOO(CCc)(c(2C)CCNcc2ccNcOcccc)=OcCc(NcC=1Cncc(O1CCOc)c2C(c(Cccc)CCcccC' for input: 'CCcCccc(SNc)C=C)NCCc2cNNcc(CcC2c2(CC)=c1C=ccNcc((cCC)C)C)1CcOSCNcnc)CcC((1c(cccccOO(CCc)(c(2C)CCNcc2ccNcOcccc)=OcCc(NcC=1Cncc(O1CCOc)c2C(c(Cccc)CCcccC'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: cc2)Oc(=C)OCCCcOO))OC)nccccN)O=Ccccc)(c2Oc=c(ONccc()(cc1OCcOOcCN1c)CcC2CNOOcCcO)c))2c=ccO1OOcclC)1OccCSc(Cc=cCCcCN)cOc2-2c1Ccc)cc)c=OCccccc1=cN2(cc1)(
# [22:44:22] SMILES Parse Error: check for mistakes around position 4:
# [22:44:22] cc2)Oc(=C)OCCCcOO))OC)nccccN)O=Ccccc)(c2O
# [22:44:22] ~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'cc2)Oc(=C)OCCCcOO))OC)nccccN)O=Ccccc)(c2Oc=c(ONccc()(cc1OCcOOcCN1c)CcC2CNOOcCcO)c))2c=ccO1OOcclC)1OccCSc(Cc=cCCcCN)cOc2-2c1Ccc)cc)c=OCccccc1=cN2(cc1)(' for input: 'cc2)Oc(=C)OCCCcOO))OC)nccccN)O=Ccccc)(c2Oc=c(ONccc()(cc1OCcOOcCN1c)CcC2CNOOcCcO)c))2c=ccO1OOcclC)1OccCSc(Cc=cCCcCN)cOc2-2c1Ccc)cc)c=OCccccc1=cN2(cc1)('
# [22:44:22] SMILES Parse Error: syntax error while parsing: )c=OccO1c1)c)ccc(O2nSCNc2c)c)ccCOcc=(c(22cc)C2cC=c=)O))C=N))Cc)2COCCN((cCcOc))c))(2C2c)cc=CC))NC)C)cC)(c(ccc=cC1Ccc)cC2c2(nC==OcCON)(C)Nc)cN2c))NcO)cc
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] )c=OccO1c1)c)ccc(O2nSCNc2c)c)ccCOcc=(c(22
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES ')c=OccO1c1)c)ccc(O2nSCNc2c)c)ccCOcc=(c(22cc)C2cC=c=)O))C=N))Cc)2COCCN((cCcOc))c))(2C2c)cc=CC))NC)C)cC)(c(ccc=cC1Ccc)cC2c2(nC==OcCON)(C)Nc)cN2c))NcO)cc' for input: ')c=OccO1c1)c)ccc(O2nSCNc2c)c)ccCOcc=(c(22cc)C2cC=c=)O))C=N))Cc)2COCCN((cCcOc))c))(2C2c)cc=CC))NC)C)cC)(c(ccc=cC1Ccc)cC2c2(nC==OcCON)(C)Nc)cN2c))NcO)cc'

# %% [markdown]
# ## 9. Generate New SMILES Strings
#
# Once the model is trained, uncomment and run this cell to generate new molecules.

# %%
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
with torch.no_grad():
	generated_smiles = sample_and_decode(model, idx_to_char, 20, 150, device)
	valid_samples, validity_rate = check_validity(generated_smiles)

print(f"\nFinal generated samples (validity rate: {validity_rate:.2%}):")
for i, s in enumerate(valid_samples[:10]):
	print(f"{i+1}. {s}")
# Out:
# Final generated samples (validity rate: 0.00%):
# [22:44:22] SMILES Parse Error: syntax error while parsing: (c)c)2cc(N=C2NccO(C)=CcCccccc=cCc))O)ccCS1c)Nc=2(22NO1=cNO)cCc)C)CcCCO2(2(cc2cC(ccc)C==cO2)c(Oc2)ccccc2cCNc2cCcCCCCc)cnccc)CccccOcccCc2ccccNOCcc)=cCCN
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] (c)c)2cc(N=C2NccO(C)=CcCccccc=cCc))O)ccCS
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '(c)c)2cc(N=C2NccO(C)=CcCccccc=cCc))O)ccCS1c)Nc=2(22NO1=cNO)cCc)C)CcCCO2(2(cc2cC(ccc)C==cO2)c(Oc2)ccccc2cCNc2cCcCCCCc)cnccc)CccccOcccCc2ccccNOCcc)=cCCN' for input: '(c)c)2cc(N=C2NccO(C)=CcCccccc=cCc))O)ccCS1c)Nc=2(22NO1=cNO)cCc)C)CcCCO2(2(cc2cC(ccc)C==cO2)c(Oc2)ccccc2cCNc2cCcCCCCc)cnccc)CccccOcccCc2ccccNOCcc)=cCCN'
# [22:44:22] SMILES Parse Error: syntax error while parsing: )cNNSccOCCOnNccC=2O2OcCCNOOccO2=1CNc)c(cO=nCO21cOcc=)c2c2cOC)c()cc))COccCc(c)C)1)c)C(Ccccc(cn)=cNN=cc)Oc1N1c)=)ccOcccC=CCccCcc(CcON))cccc))CCO2=C=c(cN
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] )cNNSccOCCOnNccC=2O2OcCCNOOccO2=1CNc)c(cO
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES ')cNNSccOCCOnNccC=2O2OcCCNOOccO2=1CNc)c(cO=nCO21cOcc=)c2c2cOC)c()cc))COccCc(c)C)1)c)C(Ccccc(cn)=cNN=cc)Oc1N1c)=)ccOcccC=CCccCcc(CcON))cccc))CCO2=C=c(cN' for input: ')cNNSccOCCOnNccC=2O2OcCCNOOccO2=1CNc)c(cO=nCO21cOcc=)c2c2cOC)c()cc))COccCc(c)C)1)c)C(Ccccc(cn)=cNN=cc)Oc1N1c)=)ccOcccC=CCccCcc(CcON))cccc))CCO2=C=c(cN'
# [22:44:22] SMILES Parse Error: syntax error while parsing: =Nc2cn)cCc)=(cO(cNc)cNccO=(CccN=ccCccO=))))=c(cO2ccCOcccO2=)c)cc1cOcccc))CcCccN2cc1c1cC)cccccnCC2c)C)2ccccCNO)2)()O)NCc)c)cOC)cc))N1cc)=CcCNO2cOCCOOcC
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] =Nc2cn)cCc)=(cO(cNc)cNccO=(CccN=ccCccO=))
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '=Nc2cn)cCc)=(cO(cNc)cNccO=(CccN=ccCccO=))))=c(cO2ccCOcccO2=)c)cc1cOcccc))CcCccN2cc1c1cC)cccccnCC2c)C)2ccccCNO)2)()O)NCc)c)cOC)cc))N1cc)=CcCNO2cOCCOOcC' for input: '=Nc2cn)cCc)=(cO(cNc)cNccO=(CccN=ccCccO=))))=c(cO2ccCOcccO2=)c)cc1cOcccc))CcCccN2cc1c1cC)cccccnCC2c)C)2ccccCNO)2)()O)NCc)c)cOC)cc))N1cc)=CcCNO2cOCCOOcC'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: NcOCNc2cccO)N(=CN(c)cC1Ccccc=2OCc()cccccccNc=()cc1ccO21cccccCOc)CCc=c))nCcO)ccCCccC))CcccccccNcc)OCCccc2N=2c1cc==COc2S2C2OcC(ccC(cc2COccN==cC(cC)NccCC
# [22:44:22] SMILES Parse Error: check for mistakes around position 12:
# [22:44:22] NcOCNc2cccO)N(=CN(c)cC1Ccccc=2OCc()cccccc
# [22:44:22] ~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'NcOCNc2cccO)N(=CN(c)cC1Ccccc=2OCc()cccccccNc=()cc1ccO21cccccCOc)CCc=c))nCcO)ccCCccC))CcccccccNcc)OCCccc2N=2c1cc==COc2S2C2OcC(ccC(cc2COccN==cC(cC)NccCC' for input: 'NcOCNc2cccO)N(=CN(c)cC1Ccccc=2OCc()cccccccNc=()cc1ccO21cccccCOc)CCc=c))nCcO)ccCCccC))CcccccccNcc)OCCccc2N=2c1cc==COc2S2C2OcC(ccC(cc2COccN==cC(cC)NccCC'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: c)cOcc1)Cc(ccCc(Nc1CcC)1c(Nc)ccCO1cCNCcccncn(cccccc))S=))NOn)=cCO11=cCc=()N=OCCc(1N(c3OCcCcc2C2c(2ccCCCncc12CcOOc((1(CcCC2cc==)CcN2cN=cNcN1)OOcCccnCOO
# [22:44:22] SMILES Parse Error: check for mistakes around position 2:
# [22:44:22] c)cOcc1)Cc(ccCc(Nc1CcC)1c(Nc)ccCO1cCNCccc
# [22:44:22] ~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'c)cOcc1)Cc(ccCc(Nc1CcC)1c(Nc)ccCO1cCNCcccncn(cccccc))S=))NOn)=cCO11=cCc=()N=OCCc(1N(c3OCcCcc2C2c(2ccCCCncc12CcOOc((1(CcCC2cc==)CcN2cN=cNcN1)OOcCccnCOO' for input: 'c)cOcc1)Cc(ccCc(Nc1CcC)1c(Nc)ccCO1cCNCcccncn(cccccc))S=))NOn)=cCO11=cCc=()N=OCCc(1N(c3OCcCcc2C2c(2ccCCCncc12CcOOc((1(CcCC2cc==)CcN2cN=cNcN1)OOcCccnCOO'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: c)O2)1)cOCOccOCCccC1CcCccc((c)((cccON(2cNc(O=C)N)ccncc1cONcOcOcCc)C)2cC2c2cCcO)CN(ncccC2cc2O)2cOCN2CcOcOccccCN2)c)C))C1NCNCccc1=Occ=(2C2N2)cc)(cc=C(Nn
# [22:44:22] SMILES Parse Error: check for mistakes around position 2:
# [22:44:22] c)O2)1)cOCOccOCCccC1CcCccc((c)((cccON(2cN
# [22:44:22] ~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'c)O2)1)cOCOccOCCccC1CcCccc((c)((cccON(2cNc(O=C)N)ccncc1cONcOcOcCc)C)2cC2c2cCcO)CN(ncccC2cc2O)2cOCN2CcOcOccccCN2)c)C))C1NCNCccc1=Occ=(2C2N2)cc)(cc=C(Nn' for input: 'c)O2)1)cOCOccOCCccC1CcCccc((c)((cccON(2cNc(O=C)N)ccncc1cONcOcOcCc)C)2cC2c2cCcO)CN(ncccC2cc2O)2cOCN2CcOcOccccCN2)c)C))C1NCNCccc1=Occ=(2C2N2)cc)(cc=C(Nn'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: OcCc)cc(ccccNC=cccccC=C)(ccNc)c=(COcc2c)cccccC(c)CC2cc)cC=c)c2NCcNccccO2cc==ccCOO2O)N)c=cO)NCc())((rc)C)CN211)OO2)cCcO2(2=cc(((cO)cONcc)Onc2ccOcN)N)=C
# [22:44:22] SMILES Parse Error: check for mistakes around position 5:
# [22:44:22] OcCc)cc(ccccNC=cccccC=C)(ccNc)c=(COcc2c)c
# [22:44:22] ~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'OcCc)cc(ccccNC=cccccC=C)(ccNc)c=(COcc2c)cccccC(c)CC2cc)cC=c)c2NCcNccccO2cc==ccCOO2O)N)c=cO)NCc())((rc)C)CN211)OO2)cCcO2(2=cc(((cO)cONcc)Onc2ccOcN)N)=C' for input: 'OcCc)cc(ccccNC=cccccC=C)(ccNc)c=(COcc2c)cccccC(c)CC2cc)cC=c)c2NCcNccccO2cc==ccCOO2O)N)c=cO)NCc())((rc)C)CN211)OO2)cCcO2(2=cc(((cO)cONcc)Onc2ccOcN)N)=C'
# [22:44:22] SMILES Parse Error: syntax error while parsing: 2O2cc2ccc2=cO()(cNc)CNCc11c(C=c)C2cc2cCcC)c(c2CcN=CccOOc=ccCcCc)CcOc2=)))cc(c(ccc2cCNc()cc)cN))nN=c)=NOcc1C)c22Oc)1=()C)C2c=O)))cC))cc)(c(cccC)))cSCCO
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] 2O2cc2ccc2=cO()(cNc)CNCc11c(C=c)C2cc2cCcC
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '2O2cc2ccc2=cO()(cNc)CNCc11c(C=c)C2cc2cCcC)c(c2CcN=CccOOc=ccCcCc)CcOc2=)))cc(c(ccc2cCNc()cc)cN))nN=c)=NOcc1C)c22Oc)1=()C)C2c=O)))cC))cc)(c(cccC)))cSCCO' for input: '2O2cc2ccc2=cO()(cNc)CNCc11c(C=c)C2cc2cCcC)c(c2CcN=CccOOc=ccCcCc)CcOc2=)))cc(c(ccc2cCNc()cc)cN))nN=c)=NOcc1C)c22Oc)1=()C)C2c=O)))cC))cc)(c(cccC)))cSCCO'
# [22:44:22] SMILES Parse Error: syntax error while parsing: 2)==COcOO1c)cNc)))c)CN(cccccCc(2((C(Sc(=(cc(C)Scccc)OcCncOCCcc(1)((c(cc=2cO=c)cccccccCcc=OCCcOcCC=cC)cCccc(c(OC)cCnSncCcccCcccCCOc1)N(c2c))NcOcN)Nc)n)
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] 2)==COcOO1c)cNc)))c)CN(cccccCc(2((C(Sc(=(
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '2)==COcOO1c)cNc)))c)CN(cccccCc(2((C(Sc(=(cc(C)Scccc)OcCncOCCcc(1)((c(cc=2cO=c)cccccccCcc=OCCcOcCC=cC)cCccc(c(OC)cCnSncCcccCcccCCOc1)N(c2c))NcOcN)Nc)n)' for input: '2)==COcOO1c)cNc)))c)CN(cccccCc(2((C(Sc(=(cc(C)Scccc)OcCncOCCcc(1)((c(cc=2cO=c)cccccccCcc=OCCcOcCC=cC)cCccc(c(OC)cCnSncCcccCcccCCOc1)N(c2c))NcOcN)Nc)n)'
# [22:44:22] SMILES Parse Error: syntax error while parsing: cc(c)=CC(c)c(c=)C2)1cC)c1)c(C)O))C(=ccc2ccc)21rcCc2nccNcCOccc(c2)Cc=N)c)OcOOCCcc(c(1(OccONcccO(C2(2OCccC2OccccOccN=cC)cc(ccCc)Nc2N)=c)c)2c=))c)(cCSNCc
# [22:44:22] SMILES Parse Error: check for mistakes around position 16:
# [22:44:22] cc(c)=CC(c)c(c=)C2)1cC)c1)c(C)O))C(=ccc2c
# [22:44:22] ~~~~~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'cc(c)=CC(c)c(c=)C2)1cC)c1)c(C)O))C(=ccc2ccc)21rcCc2nccNcCOccc(c2)Cc=N)c)OcOOCCcc(c(1(OccONcccO(C2(2OCccC2OccccOccN=cC)cc(ccCc)Nc2N)=c)c)2c=))c)(cCSNCc' for input: 'cc(c)=CC(c)c(c=)C2)1cC)c1)c(C)O))C(=ccc2ccc)21rcCc2nccNcCOccc(c2)Cc=N)c)OcOOCCcc(c(1(OccONcccO(C2(2OCccC2OccccOccN=cC)cc(ccCc)Nc2N)=c)c)2c=))c)(cCSNCc'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: O(cCcCCcNc(c=CO=CCc(CccCNCncO2c(cccOOcCCcC(n)CCC=OOcccNcN)ccccCN=ccSCcC)C)))c)C)cc)c=N)1cO)cccOcCC2ccc=(ccccOCOcccCC2=c2cC=2cN))2c=C)))ccccc))cCcC)OcN
# [22:44:22] SMILES Parse Error: check for mistakes around position 76:
# [22:44:22] cN)ccccCN=ccSCcC)C)))c)C)cc)c=N)1cO)cccOc
# [22:44:22] ~~~~~~~~~~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'O(cCcCCcNc(c=CO=CCc(CccCNCncO2c(cccOOcCCcC(n)CCC=OOcccNcN)ccccCN=ccSCcC)C)))c)C)cc)c=N)1cO)cccOcCC2ccc=(ccccOCOcccCC2=c2cC=2cN))2c=C)))ccccc))cCcC)OcN' for input: 'O(cCcCCcNc(c=CO=CCc(CccCNCncO2c(cccOOcCCcC(n)CCC=OOcccNcN)ccccCN=ccSCcC)C)))c)C)cc)c=N)1cO)cccOcCC2ccc=(ccccOCOcccCC2=c2cC=2cN))2c=C)))ccccc))cCcC)OcN'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: C(ccccc1)cNcCO)1cC2(Cccc=cc=cc)cc1)2cc(c2NN((cOnccc2ccCcc==c2c)1NcOcOcCO2c1ccc(1NcN=C(COcC)NCO=CC2ccC(cNcc=)=Oc2cc2cCC2cOC(CcccOcCcCcC=1cccccS1Oc=c)Nc
# [22:44:22] SMILES Parse Error: check for mistakes around position 15:
# [22:44:22] C(ccccc1)cNcCO)1cC2(Cccc=cc=cc)cc1)2cc(c2
# [22:44:22] ~~~~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'C(ccccc1)cNcCO)1cC2(Cccc=cc=cc)cc1)2cc(c2NN((cOnccc2ccCcc==c2c)1NcOcOcCO2c1ccc(1NcN=C(COcC)NCO=CC2ccC(cNcc=)=Oc2cc2cCC2cOC(CcccOcCcCcC=1cccccS1Oc=c)Nc' for input: 'C(ccccc1)cNcCO)1cC2(Cccc=cc=cc)cc1)2cc(c2NN((cOnccc2ccCcc==c2c)1NcOcOcCO2c1ccc(1NcN=C(COcC)NCO=CC2ccC(cNcc=)=Oc2cc2cCC2cOC(CcccOcCcCcC=1cccccS1Oc=c)Nc'
# [22:44:22] SMILES Parse Error: syntax error while parsing: CCO2(c(c)cNc()N22cOONCCcCcCNcCCccc)(c1CC)NC)())CScC))cc)cO)2C)CC)C)2cccO=cnCOccCcccc2)=)cOCcc2Cccc2cNcNNc2(cccNc=cN2)Ccc2C)cc2cccnCO1)C)COcCN2))NC(CcC
# [22:44:22] SMILES Parse Error: check for mistakes around position 14:
# [22:44:22] CCO2(c(c)cNc()N22cOONCCcCcCNcCCccc)(c1CC)
# [22:44:22] ~~~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'CCO2(c(c)cNc()N22cOONCCcCcCNcCCccc)(c1CC)NC)())CScC))cc)cO)2C)CC)C)2cccO=cnCOccCcccc2)=)cOCcc2Cccc2cNcNNc2(cccNc=cN2)Ccc2C)cc2cccnCO1)C)COcCN2))NC(CcC' for input: 'CCO2(c(c)cNc()N22cOONCCcCcCNcCCccc)(c1CC)NC)())CScC))cc)cO)2C)CC)C)2cccO=cnCOccCcccc2)=)cOCcc2Cccc2cNcNNc2(cccNc=cN2)Ccc2C)cc2cccnCO1)C)COcCN2))NC(CcC'
# [22:44:22] SMILES Parse Error: syntax error while parsing: 2cC)cc=NccCcCncC(c)OOcCC)c)OOcCccc1(CCc)1cC(cccc=Cccc2(1c2ccC2N2cNcc(C)cccO12(Ccc=2Nc)2C=CccCc2O1CCcnc=c)c12c=ccN)S2cC==c)(cOOC)Nc=cC))O=nncCcc))Ncccc
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] 2cC)cc=NccCcCncC(c)OOcCC)c)OOcCccc1(CCc)1
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '2cC)cc=NccCcCncC(c)OOcCC)c)OOcCccc1(CCc)1cC(cccc=Cccc2(1c2ccC2N2cNcc(C)cccO12(Ccc=2Nc)2C=CccCc2O1CCcnc=c)c12c=ccN)S2cC==c)(cOOC)Nc=cC))O=nncCcc))Ncccc' for input: '2cC)cc=NccCcCncC(c)OOcCC)c)OOcCccc1(CCc)1cC(cccc=Cccc2(1c2ccC2N2cNcc(C)cccO12(Ccc=2Nc)2C=CccCc2O1CCcnc=c)c12c=ccN)S2cC==c)(cOOC)Nc=cC))O=nncCcc))Ncccc'
# [22:44:22] SMILES Parse Error: syntax error while parsing: 2cCC(cc)2cOCccCcOc)N(c)(NCcccc)=c1OcC2(nCcCN)cN12NNcCc2cc(cCNccCCNc21OcNcccC)cOc=cccc2)cccc2c2)2)1C)=CcCNcc22O)ccc))CcccOc)OC=2)ccc2ccccN)N(cccCc=c)Cc
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] 2cCC(cc)2cOCccCcOc)N(c)(NCcccc)=c1OcC2(nC
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '2cCC(cc)2cOCccCcOc)N(c)(NCcccc)=c1OcC2(nCcCN)cN12NNcCc2cc(cCNccCCNc21OcNcccC)cOc=cccc2)cccc2c2)2)1C)=CcCNcc22O)ccc))CcccOc)OC=2)ccc2ccccN)N(cccCc=c)Cc' for input: '2cCC(cc)2cOCccCcOc)N(c)(NCcccc)=c1OcC2(nCcCN)cN12NNcCc2cc(cCNccCCNc21OcNcccC)cOc=cccc2)cccc2c2)2)1C)=CcCNcc22O)ccc))CcccOc)OC=2)ccc2ccccN)N(cccCc=c)Cc'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: c(C)CC1cc2c1NcCc2cc)=ccO2N1ccO)1)cOOnccNNNcCN22)1C1Nc(C)(cc(cccCC2(2cc=)ccN)CNcCCCCC(CcccO(CcC)1c1NccC)cCOc2c(O)c(cOc2)(OC=ccnc2)C)nc=ccccCOC1cO)cc2cc
# [22:44:22] SMILES Parse Error: check for mistakes around position 20:
# [22:44:22] c(C)CC1cc2c1NcCc2cc)=ccO2N1ccO)1)cOOnccNN
# [22:44:22] ~~~~~~~~~~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'c(C)CC1cc2c1NcCc2cc)=ccO2N1ccO)1)cOOnccNNNcCN22)1C1Nc(C)(cc(cccCC2(2cc=)ccN)CNcCCCCC(CcccO(CcC)1c1NccC)cCOc2c(O)c(cOc2)(OC=ccnc2)C)nc=ccccCOC1cO)cc2cc' for input: 'c(C)CC1cc2c1NcCc2cc)=ccO2N1ccO)1)cOOnccNNNcCN22)1C1Nc(C)(cc(cccCC2(2cc=)ccN)CNcCCCCC(CcccO(CcC)1c1NccC)cCOc2c(O)c(cOc2)(OC=ccnc2)C)nc=ccccCOC1cO)cc2cc'
# [22:44:22] SMILES Parse Error: syntax error while parsing: 1(cN)ccNc2O=c)2cCO)ccNNcC)cOc1(2ccccOOcccc2cCcc=c)cC)2ccCO(1))cc2(cO)ccc(1ncnC()n(()c=Nc=ccO=cCCCcNC=OcCOcOcc2O=cn(cccCN)cN(Oc))=CCN2ccOC)C)N))Nc2cNO=
# [22:44:22] SMILES Parse Error: check for mistakes around position 1:
# [22:44:22] 1(cN)ccNc2O=c)2cCO)ccNNcC)cOc1(2ccccOOccc
# [22:44:22] ^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES '1(cN)ccNc2O=c)2cCO)ccNNcC)cOc1(2ccccOOcccc2cCcc=c)cC)2ccCO(1))cc2(cO)ccc(1ncnC()n(()c=Nc=ccO=cCCCcNC=OcCOcOcc2O=cn(cccCN)cN(Oc))=CCN2ccOC)C)N))Nc2cNO=' for input: '1(cN)ccNc2O=c)2cCO)ccNNcC)cOc1(2ccccOOcccc2cCcc=c)cC)2ccCO(1))cc2(cO)ccc(1ncnC()n(()c=Nc=ccO=cCCCcNC=OcCOcOcc2O=cn(cccCN)cN(Oc))=CCN2ccOC)C)N))Nc2cNO='
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: ccc2)c(2)cc2N2c2O2=(Ccn)O)ccNc(cN)2ccccOc)(OC(2cC1cO(cN(C2=Cc=cccCc2)cNCCc)cOc)cN2=Nc1N=cc)ccOcO=N)C)ccC)=c2Oc3)c1ccOccccc=(ncc2N1cccNNc1OC(O=C(cccc)c
# [22:44:22] SMILES Parse Error: check for mistakes around position 5:
# [22:44:22] ccc2)c(2)cc2N2c2O2=(Ccn)O)ccNc(cN)2ccccOc
# [22:44:22] ~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'ccc2)c(2)cc2N2c2O2=(Ccn)O)ccNc(cN)2ccccOc)(OC(2cC1cO(cN(C2=Cc=cccCc2)cNCCc)cOc)cN2=Nc1N=cc)ccOcO=N)C)ccC)=c2Oc3)c1ccOccccc=(ncc2N1cccNNc1OC(O=C(cccc)c' for input: 'ccc2)c(2)cc2N2c2O2=(Ccn)O)ccNc(cN)2ccccOc)(OC(2cC1cO(cN(C2=Cc=cccCc2)cNCCc)cOc)cN2=Nc1N=cc)ccOcO=N)C)ccC)=c2Oc3)c1ccOccccc=(ncc2N1cccNNc1OC(O=C(cccc)c'
# [22:44:22] SMILES Parse Error: syntax error while parsing: c(=Cnc2)Nc1c(ccc)(2cccccc(ccNO2N)Oc)CcOC)cc)2(nccccCccc1cCcccCcO)O1)CC1c)CCccCc(=(CcC)Cc2ccc2ccccccccccc(2c(C2(CcC))c1ccOc(=(BCCOCCcNO2cc))cC=()ncO2)c
# [22:44:22] SMILES Parse Error: check for mistakes around position 19:
# [22:44:22] c(=Cnc2)Nc1c(ccc)(2cccccc(ccNO2N)Oc)CcOC)
# [22:44:22] ~~~~~~~~~~~~~~~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'c(=Cnc2)Nc1c(ccc)(2cccccc(ccNO2N)Oc)CcOC)cc)2(nccccCccc1cCcccCcO)O1)CC1c)CCccCc(=(CcC)Cc2ccc2ccccccccccc(2c(C2(CcC))c1ccOc(=(BCCOCCcNO2cc))cC=()ncO2)c' for input: 'c(=Cnc2)Nc1c(ccc)(2cccccc(ccNO2N)Oc)CcOC)cc)2(nccccCccc1cCcccCcO)O1)CC1c)CCccCc(=(CcC)Cc2ccc2ccccccccccc(2c(C2(CcC))c1ccOc(=(BCCOCCcNO2cc))cC=()ncO2)c'
# [22:44:22] SMILES Parse Error: extra close parentheses while parsing: nNCO)=NC(OON(c=N(1O)CcOccc)1Cccc1c)ccONc=cccc1c)OO=nN(Ncc2C(cC=1c)))cc1=)(cccccC(N)c=((=cclOc)ccc2cc=2)cC)ccCcccc(cCcCNcOS2cc(cc))cccCccc(2ccccOccCCCc
# [22:44:22] SMILES Parse Error: check for mistakes around position 5:
# [22:44:22] nNCO)=NC(OON(c=N(1O)CcOccc)1Cccc1c)ccONc=
# [22:44:22] ~~~~^
# [22:44:22] SMILES Parse Error: Failed parsing SMILES 'nNCO)=NC(OON(c=N(1O)CcOccc)1Cccc1c)ccONc=cccc1c)OO=nN(Ncc2C(cC=1c)))cc1=)(cccccC(N)c=((=cclOc)ccc2cc=2)cC)ccCcccc(cCcCNcOS2cc(cc))cccCccc(2ccccOccCCCc' for input: 'nNCO)=NC(OON(c=N(1O)CcOccc)1Cccc1c)ccONc=cccc1c)OO=nN(Ncc2C(cC=1c)))cc1=)(cccccC(N)c=((=cclOc)ccc2cc=2)cC)ccCcccc(cCcCNcOS2cc(cc))cccCccc(2ccccOccCCCc'

# %% [markdown]
# ## 10. Using Your Own Dataset
#
# You can load your own SMILES data and train the model on it.

# %%
# Load your own data
# Example 1: Loading from a CSV file with a 'smiles' column
# your_df = pd.read_csv('your_smiles_data.csv')
# smiles_list = your_df['smiles'].tolist()

# Example 2: Directly define from your data string
# long_smiles = "CCCS(=O)c1ccc2[nH]c(=NC(=O)OC)[nH]c2c11CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc12Cc1c(Cl)cccc1Nc1ncccc1C(=O)OCC(O)CO3Cn1cnc2c1c(=O)n(CC(O)CO)c(=O)n2C4CC1Oc2ccc(Cl)cc2N(CC(O)CO)C1=O"
# # Parse into individual compounds if needed
# smiles_list = [long_smiles]  # or split it if it contains multiple compounds

# Run the model
# model, char_to_idx, idx_to_char = main(smiles_list, num_epochs=50)

# %% [markdown]
# ## 11. Visualize Generated Molecules
#
# This optional section shows how to visualize generated molecules.

# %%
# Uncomment to install RDKit visualization tools
# !pip install rdkit-pypi

from rdkit.Chem import Draw
import matplotlib.pyplot as plt
from IPython.display import display

def visualize_molecules(smiles_list, ncols=3):
    mols = [Chem.MolFromSmiles(s) for s in smiles_list if Chem.MolFromSmiles(s) is not None]
    if len(mols) == 0:
        print("No valid molecules to visualize")
        return
        
    # Calculate number of rows needed
    nrows = (len(mols) + ncols - 1) // ncols
    
    # Create subplot
    fig = plt.figure(figsize=(ncols*3, nrows*3))
    
    for i, mol in enumerate(mols):
        ax = fig.add_subplot(nrows, ncols, i+1)
        img = Draw.MolToImage(mol, size=(300, 300))
        ax.imshow(img)
        ax.set_title(f"Molecule {i+1}")
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

# Example usage:
visualize_molecules(valid_samples[:9])
# Out:
# No valid molecules to visualize

# %% [markdown]
# ## 12. Save and Load Models
